# %% [markdown]
# # Wordle Step 1

# %%
import json
import numpy as np
import pandas as pd
import sqlite3
import wordlebot

from joblib import Parallel, delayed
from tqdm.notebook import tqdm

# %% [markdown]
# ## Load Data

# %%
wordle_candidates, wordle_answers = wordlebot.load_data('data')
wordle = wordle_candidates.loc[
    wordle_candidates.word.apply(lambda x: len(x)==len(set(x)))
].append(wordle_answers).reset_index(drop=True)

# %% [markdown]
# ## Compute Letter Frequencies

# %%
from wordlebot.lf import compute_letter_frequencies, compute_lf_score

lf_freqs = compute_letter_frequencies(wordle).sum().to_dict()
lf_scores = pd.DataFrame({'word': wordle.word,
                          'letter_freq': wordle.word.apply(compute_lf_score, freqs=lf_freqs)})

# %% [markdown]
# ## Compute Green/Yellow/Grey (GYX) Scores

# %%
from wordlebot.gyx import get_gyx_scores_all, compute_ncands_all, summarise_ncands

df_scores = get_gyx_scores_all(wordle, wordle_answers)
# Out:
#   0%|          | 0/9071 [00:00<?, ?it/s]
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  65 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=5)]: Done 4325 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=5)]: Done 9071 out of 9071 | elapsed:    9.4s finished

# %%
shortlist = df_scores.loc[df_scores.green_rank.le(10) | \
                          df_scores.yellow_rank.le(10) | 
                          df_scores.wt_avg_rank.le(10)]

# %% [markdown]
# ## Compute No. of Candidates

# %%
df_ncands = compute_ncands_all(shortlist, wordle_answers, wordle_answers)
df_ncands_sum = summarise_ncands(df_ncands)

# %% [markdown]
# ## Combine Results

# %%
df = shortlist.merge(df_ncands_sum, how='left', on='word')
df['ncands_max_rank'] = df.ncands_max.rank()
df['ncands_mean_rank'] = df.ncands_mean.rank()
df['bucket_entropy_rank'] = df.bucket_entropy.rank(ascending=False)
df['avg_rank'] = df[['wt_avg_rank', 'ncands_max_rank', 'bucket_entropy_rank']].mean(axis=1)

# %%
df.sort_values('avg_rank')
# Out:
#      word  green_avg  yellow_avg  weighted_avg  green_rank  yellow_rank  \
# 6   soare   0.660043    1.107991      3.088121         2.0       1561.5
# 3   saine   0.666091    0.966739      2.965011         1.0       3963.0
# 15  slate   0.620734    1.063067      2.925270         5.5       2210.0
# 5   slane   0.639309    0.993952      2.911879         4.0       3450.0
# 16  stare   0.572786    1.192657      2.911015        53.0        703.0
# 2   saice   0.653132    0.935637      2.895032         3.0       4624.0
# 19  erase   0.536069    1.397408      3.005616       221.0         37.0
# 11  tease   0.558531    1.301512      2.977106        98.0        182.0
# 20  lease   0.532181    1.319654      2.916199       243.0        143.0
# 22  cease   0.579698    1.185745      2.924838        39.5        753.5
# 13  eerie   0.457451    1.552052      2.924406      1219.0          1.0
# 14  eater   0.439309    1.515335      2.833261      1626.5          3.0
# 24  sauce   0.609503    0.897192      2.725702         9.0       5371.0
# 7   soave   0.614255    0.856587      2.699352         7.0       6157.0
# 21  slice   0.608639    0.867387      2.693305        10.0       5943.5
# 4   samey   0.610367    0.814255      2.645356         8.0       6851.0
# 17  arena   0.358963    1.481641      2.558531      4122.0          7.0
# 9   error   0.365443    1.466091      2.562419      3887.5         10.0
# 8   soily   0.620734    0.676458      2.538661         5.5       8417.0
# 23  terra   0.332613    1.527430      2.525270      5112.0          2.0
# 18  ester   0.314903    1.514039      2.458747      5756.0          4.0
# 1   retia   0.293737    1.484233      2.365443      6528.5          6.0
# 12  retro   0.288553    1.469546      2.335205      6692.0          8.0
# 10  enema   0.202160    1.469114      2.075594      8700.0          9.0
# 0   estro   0.176674    1.486825      2.016847      8897.0          5.0
#
#     wt_avg_rank  ncands_max  ncands_mean  nbuckets  bucket_entropy  \
# 6           1.0         183    62.301080       127        4.079837
# 3           4.0         207    72.592225       136        3.995355
# 15          5.0         221    71.572786       147        4.058914
# 5           9.0         225    73.985745       133        3.999585
# 16         10.0         227    71.294600       133        4.025300
# 2          11.0         211    76.517927       124        3.944870
# 19          2.0         326   114.186177        79        3.513473
# 11          3.0         347   119.062203        84        3.530741
# 20          8.0         344   121.463067        84        3.493649
# 22          6.0         370   136.372786        76        3.392527
# 13          7.0         540   219.281641        46        2.837394
# 14         31.0         332   120.651836        88        3.427816
# 24         75.0         247    95.304104       120        3.778766
# 7          96.0         244   106.639741        97        3.555947
# 21        104.0         292    96.128294       125        3.822077
# 4         160.5         287   121.466523       104        3.506692
# 17        322.0         343   133.252268        77        3.335377
# 9         312.0         554   277.815551        46        2.664727
# 8         380.5         366   126.929158       105        3.508770
# 23        426.5         332   130.850540        86        3.403144
# 18        677.0         391   158.303672        72        3.140194
# 1        1127.0         194    78.548164       125        3.838113
# 12       1290.0         378   151.211663        79        3.230027
# 10       3579.5         431   223.211663        61        2.831935
# 0        4188.5         246   106.564579       101        3.562181
#
#     ncands_max_rank  ncands_mean_rank  bucket_entropy_rank     avg_rank
# 6               1.0               1.0                  1.0     1.000000
# 3               3.0               4.0                  5.0     4.000000
# 15              5.0               3.0                  2.0     4.000000
# 5               6.0               5.0                  4.0     6.333333
# 16              7.0               2.0                  3.0     6.666667
# 2               4.0               6.0                  6.0     7.000000
# 19             13.0              12.0                 13.0     9.333333
# 11             18.0              13.0                 12.0    11.000000
# 20             17.0              15.0                 16.0    13.666667
# 22             20.0              20.0                 19.0    15.000000
# 13             24.0              23.0                 23.0    18.000000
# 14             14.5              14.0                 17.0    20.833333
# 24             10.0               8.0                  9.0    31.333333
# 7               8.0              11.0                 11.0    38.333333
# 21             12.0               9.0                  8.0    41.333333
# 4              11.0              16.0                 15.0    62.166667
# 17             16.0              19.0                 20.0   119.333333
# 9              25.0              25.0                 25.0   120.666667
# 8              19.0              17.0                 14.0   137.833333
# 23             14.5              18.0                 18.0   153.000000
# 18             22.0              22.0                 22.0   240.333333
# 1               2.0               7.0                  7.0   378.666667
# 12             21.0              21.0                 21.0   444.000000
# 10             23.0              24.0                 24.0  1208.833333
# 0               9.0              10.0                 10.0  1402.500000

# %% [markdown]
# `soare` is the optimal starter word.
