# %% [markdown]
# # Wordlebot Sim

# %%
import numpy as np
import pandas as pd
import wordlebot

from wordlebot import Wordle
from wordlebot.gyx import entropy

# %%
# Choose a seed word
input_word = 'arose'

# Choose a method: ncands (recommended), expected_gyx, lf 
method = 'ncands'

# %%
wordle_candidates, wordle_answers = wordlebot.load_data('data')
wordle = wordle_candidates.loc[
    wordle_candidates.word.apply(lambda x: len(x)==len(set(x)))
].append(wordle_answers).reset_index(drop=True)

# %%
def play_game(input_word, solution):

    game = Wordle(wordle, wordle_answers, solution=solution, verbose=False)
    
    while not game.solved:
        if game.step == 0:
            game.guess(input_word)
        else:
            game.guess(game.optimisations[method.lower()].word.iloc[0])
        game.optimise(method=method.lower(), by='ncands_max', n_jobs=-1)
        
    return game.records()

# %%
counter = 1
results = []
print(f'[ ---------- {input_word.upper()} ---------- ]')
for solution in wordle_answers.word:
    game_results = play_game(input_word, solution)
    results.append(game_results)
    if counter % 10 == 0:
        temp_df = pd.DataFrame(results)
        print(f'[Game {counter}] Range: {temp_df.steps.min()}-{temp_df.steps.max()} | ' + \
              f'Median/Mean: {temp_df.steps.median()} / {temp_df.steps.mean():.3f} | ' + \
              f'Fail: {100 * temp_df.steps.ge(7).mean():.3f}%')
    counter += 1
# Out:
# [ ---------- AROSE ---------- ]
# [Game 10] Range: 2-5 | Median/Mean: 3.5 / 3.500 | Fail: 0.000%
# [Game 20] Range: 2-5 | Median/Mean: 3.5 / 3.500 | Fail: 0.000%
# [Game 30] Range: 2-5 | Median/Mean: 3.0 / 3.433 | Fail: 0.000%
# [Game 40] Range: 2-5 | Median/Mean: 3.5 / 3.500 | Fail: 0.000%
# [Game 50] Range: 2-5 | Median/Mean: 4.0 / 3.580 | Fail: 0.000%
# [Game 60] Range: 2-5 | Median/Mean: 4.0 / 3.567 | Fail: 0.000%
# [Game 70] Range: 2-5 | Median/Mean: 4.0 / 3.571 | Fail: 0.000%
# [Game 80] Range: 2-5 | Median/Mean: 3.5 / 3.525 | Fail: 0.000%
# [Game 90] Range: 2-5 | Median/Mean: 4.0 / 3.578 | Fail: 0.000%
# [Game 100] Range: 2-5 | Median/Mean: 4.0 / 3.560 | Fail: 0.000%
# [Game 110] Range: 2-5 | Median/Mean: 4.0 / 3.555 | Fail: 0.000%
# [Game 120] Range: 2-5 | Median/Mean: 4.0 / 3.550 | Fail: 0.000%
# [Game 130] Range: 2-6 | Median/Mean: 3.5 / 3.554 | Fail: 0.000%
# [Game 140] Range: 2-6 | Median/Mean: 4.0 / 3.564 | Fail: 0.000%
# [Game 150] Range: 2-6 | Median/Mean: 4.0 / 3.573 | Fail: 0.000%
# [Game 160] Range: 2-6 | Median/Mean: 4.0 / 3.600 | Fail: 0.000%
# [Game 170] Range: 2-6 | Median/Mean: 4.0 / 3.588 | Fail: 0.000%
# [Game 180] Range: 2-6 | Median/Mean: 4.0 / 3.583 | Fail: 0.000%
# [Game 190] Range: 2-6 | Median/Mean: 4.0 / 3.600 | Fail: 0.000%

# %%
df = pd.DataFrame(results)

# %%
df.steps.describe()
# Out:
# count    2315.000000
# mean        3.573218
# std         0.801452
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         8.000000
# Name: steps, dtype: float64

# %%
df.loc[df.steps>=7]
# Out:
#       steps                                              words  \
# 49        7  [soare, lindy, bound, found, hound, mound, pound]
# 86        7  [soare, rewth, cover, joker, boxer, foyer, goner]
# 267       7  [soare, linty, caput, batch, hatch, match, watch]
# 445       7  [soare, lapse, baste, caste, haste, taste, waste]
# 463       7  [soare, linty, daunt, gaunt, haunt, jaunt, taunt]
# 786       7  [soare, score, shore, snore, spore, store, swore]
# 845       7  [soare, linty, batty, catty, fatty, patty, tatty]
# 1085      7  [soare, grace, grade, grape, grate, grave, graze]
# 1324      7  [soare, puton, brown, crown, drown, frown, grown]
# 1998      8  [soare, lindy, bound, found, hound, mound, pou...
# 2280      8  [soare, linty, daunt, gaunt, haunt, jaunt, tau...
# 2287      7  [soare, clipt, dilly, billy, filly, hilly, willy]
# 2314      7  [soare, slate, shape, shade, shake, shame, shave]
#
#                                                feedback  \
# 49    [XGXXX, XXYYX, XGGGG, XGGGG, XGGGG, XGGGG, GGGGG]
# 86    [XGXYY, YYXXX, XGXGG, XGXGG, XGXGG, XGXGG, GGGGG]
# 267   [XXYXX, XXXYX, YGXXY, XGGGG, YGGGG, XGGGG, GGGGG]
# 445   [YXYXG, XGXYG, XGGGG, XGGGG, XGGGG, YGGGG, GGGGG]
# 463   [XXYXX, XXYYX, XGGGG, XGGGG, XGGGG, XGGGG, GGGGG]
# 786   [GYXGG, GXGGG, GXGGG, GXGGG, GXGGG, GXGGG, GGGGG]
# 845   [XXYXX, XXXGG, XGGGG, XGGGG, XGGGG, XGGGG, GGGGG]
# 1085  [XXGYG, GGGXG, GGGXG, GGGXG, GGGXG, GGGXG, GGGGG]
# 1324  [XYXYX, XXXYG, XGGGG, XGGGG, XGGGG, XGGGG, GGGGG]
# 1998  [XGXXX, XXYYX, XGGGG, XGGGG, XGGGG, XGGGG, XGG...
# 2280  [XXYXX, XXYYX, XGGGG, XGGGG, XGGGG, XGGGG, YGG...
# 2287  [XXXXX, XYYXX, XGGGG, XGGGG, XGGGG, XGGGG, GGGGG]
# 2314  [GXGXG, GXGXG, GGGXG, GGGXG, GGGXG, GGGXG, GGGGG]
#
#                           ncands
# 49        [87, 6, 5, 4, 3, 2, 2]
# 86        [22, 9, 5, 3, 2, 1, 1]
# 267      [138, 9, 4, 3, 2, 1, 1]
# 445       [15, 5, 4, 3, 2, 1, 1]
# 463      [138, 6, 5, 4, 3, 2, 2]
# 786        [6, 5, 4, 3, 2, 1, 1]
# 845      [138, 5, 4, 3, 2, 1, 1]
# 1085      [19, 5, 4, 3, 2, 1, 1]
# 1324      [59, 6, 4, 3, 2, 1, 1]
# 1998   [87, 6, 5, 4, 3, 2, 1, 1]
# 2280  [138, 6, 5, 4, 3, 2, 1, 1]
# 2287    [183, 12, 4, 3, 2, 1, 1]
# 2314      [19, 9, 4, 3, 2, 1, 1]

# %%
df.to_csv('results/wordlebot_soare.csv', index=False)

# %% [markdown]
# ## Tales

# %%
input_word = 'tales'
counter = 1
results = []
for solution in wordle_answers.word:
    game_results = play_game(input_word, solution)
    results.append(game_results)
    if counter % 10 == 0:
        temp_df = pd.DataFrame(results)
        print(f'[Game {counter}] Range: {temp_df.steps.min()}-{temp_df.steps.max()} | ' + \
              f'Median/Mean: {temp_df.steps.median()} / {temp_df.steps.mean():.3f} | ' + \
              f'Fail: {100 * temp_df.steps.ge(7).mean():.3f}%')
    counter += 1
# Out:
# [Game 10] Range: 3-4 | Median/Mean: 4.0 / 3.600 | Fail: 0.000%
# [Game 20] Range: 3-4 | Median/Mean: 4.0 / 3.650 | Fail: 0.000%
# [Game 30] Range: 3-4 | Median/Mean: 3.5 / 3.500 | Fail: 0.000%
# [Game 40] Range: 2-4 | Median/Mean: 3.0 / 3.450 | Fail: 0.000%
# [Game 50] Range: 2-7 | Median/Mean: 3.5 / 3.560 | Fail: 2.000%
# [Game 60] Range: 2-7 | Median/Mean: 3.5 / 3.583 | Fail: 1.667%
# [Game 70] Range: 2-7 | Median/Mean: 4.0 / 3.629 | Fail: 1.429%
# [Game 80] Range: 2-7 | Median/Mean: 4.0 / 3.587 | Fail: 1.250%
# [Game 90] Range: 2-7 | Median/Mean: 4.0 / 3.578 | Fail: 1.111%
# [Game 100] Range: 2-7 | Median/Mean: 3.0 / 3.520 | Fail: 1.000%
# [Game 110] Range: 2-7 | Median/Mean: 3.5 / 3.536 | Fail: 0.909%
# [Game 120] Range: 2-7 | Median/Mean: 3.0 / 3.533 | Fail: 0.833%
# [Game 130] Range: 2-7 | Median/Mean: 3.0 / 3.515 | Fail: 0.769%
# [Game 140] Range: 2-7 | Median/Mean: 3.0 / 3.500 | Fail: 0.714%
# [Game 150] Range: 2-7 | Median/Mean: 3.0 / 3.533 | Fail: 0.667%
# [Game 160] Range: 2-7 | Median/Mean: 3.0 / 3.550 | Fail: 0.625%
# [Game 170] Range: 2-7 | Median/Mean: 3.0 / 3.541 | Fail: 0.588%
# [Game 180] Range: 2-7 | Median/Mean: 3.0 / 3.522 | Fail: 0.556%
# [Game 190] Range: 2-7 | Median/Mean: 3.0 / 3.532 | Fail: 0.526%
# [Game 200] Range: 2-7 | Median/Mean: 3.0 / 3.525 | Fail: 0.500%
# [Game 210] Range: 2-7 | Median/Mean: 3.0 / 3.514 | Fail: 0.476%
# [Game 220] Range: 2-7 | Median/Mean: 3.0 / 3.523 | Fail: 0.455%
# [Game 230] Range: 2-7 | Median/Mean: 3.0 / 3.539 | Fail: 0.435%
# [Game 240] Range: 2-7 | Median/Mean: 3.0 / 3.538 | Fail: 0.417%
# [Game 250] Range: 2-7 | Median/Mean: 3.0 / 3.532 | Fail: 0.400%
# [Game 260] Range: 2-7 | Median/Mean: 3.0 / 3.527 | Fail: 0.385%
# [Game 270] Range: 2-7 | Median/Mean: 3.0 / 3.526 | Fail: 0.741%
# [Game 280] Range: 2-7 | Median/Mean: 3.0 / 3.511 | Fail: 0.714%
# [Game 290] Range: 2-7 | Median/Mean: 3.0 / 3.524 | Fail: 0.690%
# [Game 300] Range: 2-7 | Median/Mean: 3.0 / 3.520 | Fail: 0.667%
# [Game 310] Range: 2-7 | Median/Mean: 3.0 / 3.519 | Fail: 0.645%
# [Game 320] Range: 2-7 | Median/Mean: 3.0 / 3.513 | Fail: 0.625%
# [Game 330] Range: 2-7 | Median/Mean: 3.0 / 3.515 | Fail: 0.606%
# [Game 340] Range: 2-7 | Median/Mean: 3.0 / 3.521 | Fail: 0.588%
# [Game 350] Range: 2-7 | Median/Mean: 3.0 / 3.520 | Fail: 0.571%
# [Game 360] Range: 2-7 | Median/Mean: 3.0 / 3.511 | Fail: 0.556%
# [Game 370] Range: 2-7 | Median/Mean: 3.0 / 3.514 | Fail: 0.541%
# [Game 380] Range: 2-7 | Median/Mean: 3.0 / 3.513 | Fail: 0.526%
# [Game 390] Range: 2-7 | Median/Mean: 3.0 / 3.515 | Fail: 0.513%
# [Game 400] Range: 2-7 | Median/Mean: 3.0 / 3.520 | Fail: 0.500%
# [Game 410] Range: 2-7 | Median/Mean: 3.0 / 3.534 | Fail: 0.488%
# [Game 420] Range: 2-7 | Median/Mean: 3.0 / 3.545 | Fail: 0.476%
# [Game 430] Range: 2-7 | Median/Mean: 3.0 / 3.549 | Fail: 0.465%
# [Game 440] Range: 2-7 | Median/Mean: 3.0 / 3.559 | Fail: 0.455%
# [Game 450] Range: 2-7 | Median/Mean: 3.0 / 3.562 | Fail: 0.444%
# [Game 460] Range: 2-7 | Median/Mean: 3.0 / 3.570 | Fail: 0.435%
# [Game 470] Range: 2-7 | Median/Mean: 4.0 / 3.574 | Fail: 0.426%
# [Game 480] Range: 2-7 | Median/Mean: 3.5 / 3.571 | Fail: 0.417%
# [Game 490] Range: 2-7 | Median/Mean: 3.0 / 3.567 | Fail: 0.408%
# [Game 500] Range: 2-7 | Median/Mean: 3.0 / 3.564 | Fail: 0.400%
# [Game 510] Range: 2-7 | Median/Mean: 3.0 / 3.563 | Fail: 0.392%
# [Game 520] Range: 2-7 | Median/Mean: 3.5 / 3.571 | Fail: 0.385%
# [Game 530] Range: 2-7 | Median/Mean: 3.0 / 3.566 | Fail: 0.377%
# [Game 540] Range: 2-7 | Median/Mean: 4.0 / 3.570 | Fail: 0.370%
# [Game 550] Range: 2-7 | Median/Mean: 4.0 / 3.569 | Fail: 0.364%
# [Game 560] Range: 2-7 | Median/Mean: 3.5 / 3.568 | Fail: 0.357%
# [Game 570] Range: 2-7 | Median/Mean: 3.0 / 3.561 | Fail: 0.351%
# [Game 580] Range: 2-7 | Median/Mean: 3.0 / 3.559 | Fail: 0.345%
# [Game 590] Range: 2-7 | Median/Mean: 4.0 / 3.564 | Fail: 0.339%
# [Game 600] Range: 2-7 | Median/Mean: 4.0 / 3.567 | Fail: 0.333%
# [Game 610] Range: 2-7 | Median/Mean: 4.0 / 3.569 | Fail: 0.328%
# [Game 620] Range: 2-7 | Median/Mean: 4.0 / 3.568 | Fail: 0.323%
# [Game 630] Range: 2-7 | Median/Mean: 4.0 / 3.571 | Fail: 0.317%
# [Game 640] Range: 2-7 | Median/Mean: 4.0 / 3.572 | Fail: 0.312%
# [Game 650] Range: 2-7 | Median/Mean: 4.0 / 3.572 | Fail: 0.308%
# [Game 660] Range: 2-7 | Median/Mean: 4.0 / 3.568 | Fail: 0.303%
