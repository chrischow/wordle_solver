# %% [markdown]
# # Post

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from joblib import Parallel, delayed

sns.set()

# %% [markdown]
# ## Load Words

# %%
with open('data/wordle-candidates.json', 'r') as file:
    wordle_candidates = json.load(file)
    
with open('data/wordle-answers.json', 'r') as file:
    wordle_answers = json.load(file)

wordle_candidates = pd.DataFrame(wordle_candidates['words'], columns=['word'])
wordle_answers = pd.DataFrame(wordle_answers['words'], columns=['word'])
wordle_candidates['is_answer'] = 0
wordle_answers['is_answer'] = 1
wordle = wordle_candidates.append(wordle_answers).reset_index(drop=True)

# %% [markdown]
# ## Game Logic

# %%
def get_feedback(input_word, solution):
    output = ''
    for i in range(5):
        if input_word[i] == solution[i]:
            output += 'G'
        elif input_word[i] in solution:
            output += 'Y'
        else:
            output += 'X'
    return output

# %%
def filter_wordset(input_word, feedback, wordset):
    newset = wordset.copy()
    for i in range(5):
        if feedback[i] == 'G':
            newset = newset.loc[newset.word.str[i] == input_word[i]]
        elif feedback[i] == 'Y':
            # newset = newset.loc[newset.word.str.contains(input_word[i])]
            newset = newset.loc[newset.word.str.contains(input_word[i]) & newset.word.apply(lambda x: x[i] != input_word[i])]
        else:
            newset = newset.loc[~newset.word.str.contains(input_word[i])]
    return newset

# %% [markdown]
# ## Level 1: Global Letter Frequency

# %%
def compute_letter_frequencies(wordset):
    w = wordset.copy()
    for letter in list('abcdefghijklmnopqrstuvwxyz'):
        w[letter] = w.word.str.contains(letter).astype(int)
    return w.iloc[:, 1:]

def compute_score(x, freqs):
    letters = set(x)
    output = 0
    for letter in letters:
        output += freqs[letter]
    return output

# %%
global_freqs = compute_letter_frequencies(wordle).sum().to_dict()
global_scores = wordle.word.apply(compute_score, freqs=global_freqs)
global_scores = pd.DataFrame({'word': wordle.word, 'score': global_scores}).sort_values('score', ascending=False)

compute_letter_frequencies(wordle).sum().sort_values().plot.barh(figsize=(12,6))
plt.title('Global Letter Frequencies', fontdict={'fontsize': 15})
plt.show()

plot_words = global_scores.head(10).reset_index(drop=True)
plot_words.set_index('word').plot.barh(figsize=(12,6), legend=None)
plt.gca().invert_yaxis()
plt.title('Scores for 13k 5-letter Words', fontdict={'fontsize': 15})
for i, row in plot_words.iterrows():
    plt.text(row.score+100, i+0.1, row.score)
plt.show()

# %% [markdown]
# ### Single

# %%
def sim_wordle(input_word, solution):
    feedback = ''
    wordset = wordle.copy()
    tested_words = []
    n_iter = 1

    while feedback != 'GGGGG':

        # Check solution
        feedback = get_feedback(input_word, solution)
        tested_words.append(input_word)

        # Filter wordset
        wordset = filter_wordset(input_word, feedback, wordset)
        wordset = wordset.loc[~wordset.word.isin(tested_words)]

        # Compute letter distribution of updated wordset
        wordset_letterdist = compute_letter_frequencies(wordset)
        freqs = wordset_letterdist.sum().to_dict()

        # Obtain scores
        scores = wordset.word.apply(compute_score, freqs=freqs)
        scores = pd.DataFrame({'word': wordset.word, 'score': scores}).sort_values('score', ascending=False)

        # Set new input word
        if scores.shape[0] > 0:
            input_word = scores.word.iloc[0]
            n_iter += 1
    return n_iter

# %%
def global_lf_strategy(input_word):
    results = Parallel(n_jobs=5, verbose=3)(delayed(sim_wordle)(input_word, s) for s in wordle_answers.word)
    performance = pd.Series(results)
    
    results = pd.DataFrame(performance.describe()).T
    results['word'] = input_word
    results['iter_2_or_less'] = np.mean(performance <= 2)
    results['iter_3'] = np.mean(performance == 3)
    results['iter_4'] = np.mean(performance == 4)
    results['iter_5'] = np.mean(performance == 5)
    results['iter_6'] = np.mean(performance == 6)
    results['fail'] = np.mean(performance > 6)
    display(results)
    
    return results, performance

# %%
top_singles = global_scores.groupby('score').first().sort_index(ascending=False).head(10).word.tolist()
top_singles += ['notes', 'resin', 'tares', 'senor']
print(top_singles)
# Out:
# ['aeros', 'aesir', 'aloes', 'rales', 'stoae', 'arets', 'aisle', 'aeons', 'nears', 'saine', 'notes', 'resin', 'tares', 'senor']

# %%
df_global_lf = pd.DataFrame()
# detailed_runs = wordle_answers[['word']]
for input_word in top_singles:
    print('--------------------')
    print(input_word)
    print('--------------------')
    res, _ = global_lf_strategy(input_word)
    df_global_lf = df_global_lf.append(res)
    print()
    print()
    print()
# Out:
# --------------------
# aeros
# --------------------
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=5)]: Done 176 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=5)]: Done 496 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=5)]: Done 944 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=5)]: Done 1520 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=5)]: Done 2224 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=5)]: Done 2306 out of 2315 | elapsed:   51.7s remaining:    0.2s
# [Parallel(n_jobs=5)]: Done 2315 out of 2315 | elapsed:   51.9s finished
#     count      mean       std  min  25%  50%  75%   max   word  \
# 0  2315.0  4.808639  1.390831  2.0  4.0  5.0  5.0  13.0  aeros
#
#    iter_2_or_less   iter_3    iter_4   iter_5    iter_6      fail
# 0        0.011663  0.11879  0.348596  0.27905  0.128726  0.113175
# --------------------
# aesir
# --------------------
# ...

# %%
df_global_lf.to_csv('global_lf.csv', index=False)

# %%
df_global_lf = df_global_lf.reset_index(drop=True)

# %%
df_global_lf[['word', 'mean', 'iter_2_or_less', 'iter_3', 'iter_4', 'iter_5', 'iter_6', 'fail']] \
    .sort_values('mean') \
    .rename(columns={'word': 'Word', 'mean': 'Average Turns to Solve',
                    'iter_2_or_less': '% <=2 Turns', 'iter_3': '% 3 Turns',
                    'iter_4': '% 4 Turns', 'iter_5': '% 5 Turns',
                    'iter_6': '% 6 Turns', 'fail': '% Failed to Solve'})
# Out:
#     Word  Average Turns to Solve  % <=2 Turns  % 3 Turns  % 4 Turns  \
# 0  tares                4.665227     0.013391   0.144276   0.359395
# 0  arets                4.683369     0.012527   0.142981   0.365443
# 0  saine                4.709719     0.015983   0.134773   0.359395
# 0  notes                4.738229     0.009071   0.134773   0.344708
# 0  senor                4.739525     0.012959   0.132613   0.354212
# 0  resin                4.742549     0.013391   0.128726   0.353780
# 0  rales                4.746004     0.009503   0.128294   0.349460
# 0  aisle                4.746868     0.013391   0.135205   0.340821
# 0  aeons                4.758099     0.010799   0.126134   0.364147
# 0  aloes                4.761123     0.009935   0.130454   0.351188
# 0  stoae                4.762419     0.014255   0.116631   0.362851
# 0  nears                4.771058     0.010799   0.133045   0.337797
# 0  aesir                4.790929     0.012095   0.123110   0.349892
# ...

# %%
palette = ['#7B73F0', '#27DDCB', '#27DDCB', '#7B73F0', '#7B73F0',
          '#7B73F0', '#27DDCB', '#27DDCB', '#27DDCB', '#27DDCB',
          '#27DDCB', '#27DDCB', '#27DDCB', '#27DDCB']
plt.figure(figsize=(12, 6))
sns.barplot(x='mean', y='word', data=df_global_lf.sort_values('mean'),
            palette=palette)
plt.title('Average Turns Required for Solution', fontdict={'fontsize': 15})
plt.xlabel('Average No. of Turns')
plt.xlim(4, 5)

from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#7B73F0', edgecolor='#7B73F0', label='Wired.com'),
    Patch(facecolor='#27DDCB', edgecolor='#27DDCB', label='Global LF')]

for i, row in df_global_lf.sort_values('mean', ascending=True).reset_index(drop=True).iterrows():
    plt.text(row['mean']+0.01, i+0.2, f"{row['mean']:.2f}")
plt.legend(handles=legend_elements)
plt.show()

# %% [markdown]
# ### Double

# %%
def sim_wordle_double(input_word1, input_word2, solution):
    feedback = ''
    wordset = wordle.copy()
    tested_words = []
    n_iter = 1
    
    input_word = input_word1

    while feedback != 'GGGGG':

        # Check solution
        feedback = get_feedback(input_word, solution)
        tested_words.append(input_word)
        # print(f'[{n_iter}] Input: {input_word} | Feedback: {feedback}')

        # Filter wordset
        wordset = filter_wordset(input_word, feedback, wordset)
        wordset = wordset.loc[~wordset.word.isin(tested_words)]

        # Compute letter frequencies of updated wordset
        wordset_letterdist = compute_letter_frequencies(wordset)
        freqs = wordset_letterdist.sum().to_dict()

        # Obtain scores
        scores = wordset.word.apply(compute_score, freqs=freqs)
        scores = pd.DataFrame({'word': wordset.word, 'score': scores}).sort_values('score', ascending=False)
        # display(scores.head(10))

        # Set new input word
        if scores.shape[0] > 0:
            if len(tested_words) < 2:
                input_word = input_word2
            else:
                input_word = scores.word.iloc[0]
            n_iter += 1
    return n_iter

# %%
def find_second_word(word, two_vowel=True):
    letters = list(word)
    candidates = global_scores.loc[global_scores.word.apply(lambda x: all([l not in letters for l in x]))]
    candidates = candidates.loc[candidates.word.apply(lambda x: len(x) == len(set(x)))]
    if two_vowel:
        candidates = candidates.loc[
            candidates.word.apply(lambda x: x.count('a') + x.count('e') + \
                                  x.count('i') + x.count('o') + x.count('u') >= 2)
        ]
    candidates = candidates.groupby('score').first().sort_index(ascending=False)
    return candidates.head(3)

# %%
def global_lf_strategy_double(input_word1, input_word2):
    results = Parallel(n_jobs=5, verbose=3)(delayed(sim_wordle_double)(input_word1, input_word2, s) for s in wordle_answers.word)
    performance = pd.Series(results)
    
    results = pd.DataFrame(performance.describe()).T
    results['word1'] = input_word1
    results['word2'] = input_word2
    results['iter_2_or_less'] = np.mean(performance <= 2)
    results['iter_3'] = np.mean(performance == 3)
    results['iter_4'] = np.mean(performance == 4)
    results['iter_5'] = np.mean(performance == 5)
    results['iter_6'] = np.mean(performance == 6)
    results['fail'] = np.mean(performance > 6)
    display(results)
    
    return results, performance

# %%
for input_word1 in ['tares', 'saine', 'notes', 'senor', 'resin']:
    print('----------------------------------')
    print(input_word1)
    print('----------------------------------')
    all_word2 = find_second_word(input_word1).word.tolist()
    if input_word1 == 'tares':
        all_word2 += ['chino']
    elif input_word1 == 'notes':
        all_word2 += ['acrid']
    elif input_word1 == 'senor':
        all_word2 += ['ducat']
    elif input_word1 == 'resin':
        all_word2 += ['loath']
    print(all_word2)
# Out:
# ----------------------------------
# tares
# ----------------------------------
# ['indol', 'noily', 'nicol', 'chino']
# ----------------------------------
# saine
# ----------------------------------
# ['loury', 'yourt', 'clour']
# ----------------------------------
# notes
# ----------------------------------
# ['urial', 'drail', 'lairy', 'acrid']
# ----------------------------------
# senor
# ----------------------------------
# ['tidal', 'laity', 'ictal', 'ducat']
# ----------------------------------
# resin
# ----------------------------------
# ['dotal', 'octal', 'ploat', 'loath']

# %%
df_global_lf_double = pd.DataFrame()
for input_word1 in ['tares', 'saine', 'notes', 'senor', 'resin']:
    print('----------------------------------')
    print(input_word1)
    print('----------------------------------')
    all_word2 = find_second_word(input_word1).word.tolist()
    if input_word1 == 'tares':
        all_word2 += ['chino']
    elif input_word1 == 'notes':
        all_word2 += ['acrid']
    elif input_word1 == 'senor':
        all_word2 += ['ducat']
    elif input_word1 == 'resin':
        all_word2 += ['loath']
    print(all_word2)

    for input_word2 in all_word2:
        print(f'[---- {input_word1}, {input_word2} ----]')
        res, _ = global_lf_strategy_double(input_word1, input_word2)
        df_global_lf_double = df_global_lf_double.append(res)
# Out:
# ----------------------------------
# tares
# ----------------------------------
# ['indol', 'noily', 'nicol', 'chino']
# [---- tares, indol ----]
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=5)]: Done 126 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=5)]: Done 446 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=5)]: Done 894 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=5)]: Done 1470 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=5)]: Done 2174 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=5)]: Done 2306 out of 2315 | elapsed:   51.5s remaining:    0.2s
# [Parallel(n_jobs=5)]: Done 2315 out of 2315 | elapsed:   51.7s finished
#     count      mean       std  min  25%  50%  75%   max  word1  word2  \
# 0  2315.0  4.606048  1.174991  3.0  4.0  4.0  5.0  10.0  tares  indol
#
#    iter_2_or_less    iter_3   iter_4    iter_5    iter_6      fail
# ...

# %%
df_global_lf_double.to_csv('global_lf_double.csv', index=False)

# %%
df_global_lf_double = df_global_lf_double.reset_index(drop=True)
df_global_lf_double['words'] = df_global_lf_double.word1 + ', ' + df_global_lf_double.word2

# %%
df_global_lf_double[['words', 'mean', 'iter_2_or_less', 'iter_3', 'iter_4', 'iter_5', 'iter_6', 'fail']] \
    .sort_values('mean') \
    .rename(columns={'words': 'Words', 'mean': 'Average Turns to Solve',
                    'iter_2_or_less': '% <=2 Turns', 'iter_3': '% 3 Turns',
                    'iter_4': '% 4 Turns', 'iter_5': '% 5 Turns',
                    'iter_6': '% 6 Turns', 'fail': '% Failed to Solve'})
# Out:
#            Words  Average Turns to Solve  % <=2 Turns  % 3 Turns  % 4 Turns  \
# 17  resin, ploat                4.556803     0.000432   0.142549   0.408207
# 14  senor, ducat                4.579266     0.000000   0.150324   0.403456
# 3   tares, chino                4.579698     0.000000   0.167603   0.370626
# 11  senor, tidal                4.584881     0.000432   0.145140   0.402592
# 8   notes, drail                4.590497     0.000000   0.140389   0.404752
# 2   tares, nicol                4.602160     0.000000   0.149892   0.391793
# 0   tares, indol                4.606048     0.000000   0.139957   0.395680
# 13  senor, ictal                4.614255     0.000000   0.142549   0.396976
# 10  notes, acrid                4.614255     0.000432   0.140389   0.390497
# 15  resin, dotal                4.619006     0.000432   0.133909   0.395248
# 18  resin, loath                4.629806     0.000864   0.128726   0.405184
# ...

# %%
G = '#27DDCB'
P = '#7B73F0'
palette = [
    G,P,P,G,G,G,G,G,P,G,P,G,G,G,G,G,G,G,G
]
plt.figure(figsize=(12, 6))
sns.barplot(x='mean', y='words', data=df_global_lf_double.sort_values('mean'), palette=palette)
plt.title('Average Turns Required for Solution', fontdict={'fontsize': 15})
plt.xlabel('Average No. of Turns')
plt.xlim(4, 5)

from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#7B73F0', edgecolor='#7B73F0', label='Wired.com'),
    Patch(facecolor='#27DDCB', edgecolor='#27DDCB', label='Global LF')]

for i, row in df_global_lf_double.sort_values('mean', ascending=True).reset_index(drop=True).iterrows():
    plt.text(row['mean']+0.01, i+0.2, f"{row['mean']:.2f}")
plt.legend(handles=legend_elements)
plt.show()

# %% [markdown]
# ## Positional Letter Frequency

# %%
def compute_pos_letter_freq(wordset):
    pos_scores = {}
    pos_scores[0] = wordset.word.str[0].value_counts().to_dict()
    pos_scores[1] = wordset.word.str[1].value_counts().to_dict()
    pos_scores[2] = wordset.word.str[2].value_counts().to_dict()
    pos_scores[3] = wordset.word.str[3].value_counts().to_dict()
    pos_scores[4] = wordset.word.str[4].value_counts().to_dict()
    
    return pos_scores

# %%
pos_scores = compute_pos_letter_freq(wordle)

# %%
pos_df = pd.DataFrame(pos_scores.values()).T
pos_df[0].plot.barh(color='#7B73F0', figsize=(12,8))

for i, row in pos_df.reset_index().iterrows():
    plt.text(row[0]+10, i+0.2, row[0], fontsize=10)

plt.gca().invert_yaxis()
plt.title('Letter Frequency at Position 1', fontdict={'fontsize': 15})
plt.show()

# %%
pos_df = pd.DataFrame(pos_scores.values()).T.sort_values(4, ascending=False)
pos_df[4].plot.barh(color='#7B73F0', figsize=(12,8))

for i, row in pos_df.reset_index().iterrows():
    plt.text(row[4]+10, i+0.2, row[4], fontsize=10)

plt.gca().invert_yaxis()
plt.title('Letter Frequency at Position 5', fontdict={'fontsize': 15})
plt.show()

# %%
def compute_pos_score(letters, pos_scores):
    output = 0
    for i, letter in enumerate(letters):
        output += pos_scores[i].get(letter, 0)
    return output

# %%
pos_lf_scores = wordle.word.apply(compute_pos_score, pos_scores=pos_scores)
pos_lf_scores = pd.DataFrame({'word': wordle.word, 'score': pos_lf_scores}).sort_values('score', ascending=False)

# %% [markdown]
# ### Single

# %%
def sim_wordle_poslf(input_word, solution):
    feedback = ''
    wordset = wordle.copy()
    tested_words = []
    n_iter = 1

    while feedback != 'GGGGG':

        # Check solution
        feedback = get_feedback(input_word, solution)
        tested_words.append(input_word)
        # print(f'[{n_iter}] Input: {input_word} | Feedback: {feedback}')

        # Filter wordset
        wordset = filter_wordset(input_word, feedback, wordset)
        wordset = wordset.loc[~wordset.word.isin(tested_words)]

        # Compute letter distribution of updated wordset
        pos_scores = compute_pos_letter_freq(wordset)

        # Obtain scores
        scores = wordset.word.apply(compute_pos_score, pos_scores=pos_scores)
        scores = pd.DataFrame({'word': wordset.word, 'score': scores}).sort_values('score', ascending=False)
        scores = scores.sort_values(['score'], ascending=False)
        # display(scores.head(10))

        # Set new input word
        if scores.shape[0] > 0:
            input_word = scores.word.iloc[0]
            n_iter += 1
    return n_iter

# %%
def pos_lf_strategy(input_word):
    results = Parallel(n_jobs=5, verbose=3)(delayed(sim_wordle_poslf)(input_word, s) for s in wordle_answers.word)
    performance = pd.Series(results)
    
    results = pd.DataFrame(performance.describe()).T
    results['word'] = input_word
    results['iter_2_or_less'] = np.mean(performance <= 2)
    results['iter_3'] = np.mean(performance == 3)
    results['iter_4'] = np.mean(performance == 4)
    results['iter_5'] = np.mean(performance == 5)
    results['iter_6'] = np.mean(performance == 6)
    results['fail'] = np.mean(performance > 6)
    display(results)
    
    return results, performance

# %%
top_singles = pos_lf_scores.loc[pos_lf_scores.word.apply(lambda x: len(x) == len(set(x)))].head(10).word.tolist()
top_singles += ['notes', 'resin', 'senor']
print(top_singles)
# Out:
# ['cares', 'bares', 'pares', 'tares', 'cores', 'bores', 'mares', 'pores', 'canes', 'dares', 'notes', 'resin', 'senor']

# %%
df_pos_lf = pd.DataFrame()
# detailed_runs = wordle_answers[['word']]
for input_word in top_singles:
    print('--------------------')
    print(input_word)
    print('--------------------')
    res, _ = pos_lf_strategy(input_word)
    df_pos_lf = df_pos_lf.append(res)
    print()
    print()
    print()
# Out:
# --------------------
# cares
# --------------------
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=5)]: Done 377 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=5)]: Done 1017 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=5)]: Done 1913 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=5)]: Done 2306 out of 2315 | elapsed:   22.4s remaining:    0.1s
# [Parallel(n_jobs=5)]: Done 2315 out of 2315 | elapsed:   22.4s finished
#     count     mean       std  min  25%  50%  75%   max   word  iter_2_or_less  \
# 0  2315.0  5.02419  1.451111  2.0  4.0  5.0  6.0  12.0  cares        0.010799
#
#     iter_3    iter_4    iter_5    iter_6      fail
# 0  0.10108  0.279914  0.295464  0.184449  0.128294
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# --------------------
# bares
# --------------------
# ...

# %%
df_pos_lf.to_csv('pos_lf.csv', index=False)

# %%
df_pos_lf[['word', 'mean', 'iter_2_or_less', 'iter_3', 'iter_4', 'iter_5', 'iter_6', 'fail']] \
    .sort_values('mean') \
    .rename(columns={'word': 'Word', 'mean': 'Average Turns to Solve',
                    'iter_2_or_less': '% <=2 Turns', 'iter_3': '% 3 Turns',
                    'iter_4': '% 4 Turns', 'iter_5': '% 5 Turns',
                    'iter_6': '% 6 Turns', 'fail': '% Failed to Solve'})
# Out:
#     Word  Average Turns to Solve  % <=2 Turns  % 3 Turns  % 4 Turns  \
# 0  notes                4.964579     0.014255   0.098488   0.286825
# 0  pares                4.974946     0.010367   0.098488   0.284665
# 0  tares                4.977106     0.010799   0.102376   0.290713
# 0  canes                4.979698     0.008207   0.104104   0.288985
# 0  dares                5.006048     0.007343   0.092873   0.282073
# 0  cores                5.010367     0.014687   0.098920   0.285097
# 0  pores                5.010799     0.013391   0.096760   0.279050
# 0  cares                5.024190     0.010799   0.101080   0.279914
# 0  mares                5.043197     0.007343   0.089417   0.275594
# 0  senor                5.052700     0.009935   0.099784   0.268683
# 0  bores                5.054428     0.009503   0.095896   0.274298
# 0  bares                5.075162     0.008207   0.096328   0.257019
# 0  resin                5.114903     0.009935   0.090713   0.260907
#
# ...

# %%
palette = [P,G,P,G,G,G,G,G,G,P,G,G,P]
plt.figure(figsize=(12, 6))
sns.barplot(x='mean', y='word', data=df_pos_lf.sort_values('mean'),
            palette=palette)
plt.title('Average Turns Required for Solution', fontdict={'fontsize': 15})
plt.xlabel('Average No. of Turns')
plt.xlim(4, 5.3)

from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#7B73F0', edgecolor='#7B73F0', label='Wired.com'),
    Patch(facecolor='#27DDCB', edgecolor='#27DDCB', label='Global LF')]

for i, row in df_pos_lf.sort_values('mean', ascending=True).reset_index(drop=True).iterrows():
    plt.text(row['mean']+0.01, i+0.2, f"{row['mean']:.2f}")
plt.legend(handles=legend_elements)
plt.show()

# %% [markdown]
# ### Double

# %%
def sim_wordle_poslf_double(input_word1, input_word2, solution):
    feedback = ''
    wordset = wordle.copy()
    tested_words = []
    n_iter = 1
    
    input_word = input_word1

    while feedback != 'GGGGG':

        # Check solution
        feedback = get_feedback(input_word, solution)
        tested_words.append(input_word)
        # print(f'[{n_iter}] Input: {input_word} | Feedback: {feedback}')

        # Filter wordset
        wordset = filter_wordset(input_word, feedback, wordset)
        wordset = wordset.loc[~wordset.word.isin(tested_words)]

        # Compute letter distribution of updated wordset
        pos_scores = compute_pos_letter_distribution(wordset)

        # Obtain scores
        scores = wordset.word.apply(compute_pos_score, pos_scores=pos_scores)
        scores = pd.DataFrame({'word': wordset.word, 'score': scores}).sort_values('score', ascending=False)
        scores = scores.sort_values('score', ascending=False)
        # display(scores.head(10))

        # Set new input word
        if scores.shape[0] > 0:
            if len(tested_words) < 2:
                input_word = input_word2
            else:
                input_word = scores.word.iloc[0]
            n_iter += 1
    return n_iter

# %%
def find_second_word_pos(word, two_vowel=True):
    letters = list(word)
    candidates = pos_lf_scores.loc[pos_lf_scores.word.apply(lambda x: all([l not in letters for l in x]))]
    candidates = candidates.loc[candidates.word.apply(lambda x: len(x) == len(set(x)))]
    if two_vowel:
        candidates = candidates.loc[
            candidates.word.apply(lambda x: x.count('a') + x.count('e') + \
                                  x.count('i') + x.count('o') + x.count('u') >= 2)
        ]
    candidates = candidates.groupby('score').first().sort_index(ascending=False)
    return candidates.head(4)

# %%
def pos_lf_strategy_double(input_word1, input_word2):
    results = Parallel(n_jobs=5, verbose=3)(delayed(sim_wordle_double)(input_word1, input_word2, s) for s in wordle_answers.word)
    performance = pd.Series(results)
    
    results = pd.DataFrame(performance.describe()).T
    results['word1'] = input_word1
    results['word2'] = input_word2
    results['iter_2_or_less'] = np.mean(performance <= 2)
    results['iter_3'] = np.mean(performance == 3)
    results['iter_4'] = np.mean(performance == 4)
    results['iter_5'] = np.mean(performance == 5)
    results['iter_6'] = np.mean(performance == 6)
    results['fail'] = np.mean(performance > 6)
    display(results)
    
    return results, performance

# %%
for input_word1 in ['notes', 'pares', 'tares', 'canes', 'dares', 'senor', 'resin']:
    print('----------------------------------')
    print(input_word1)
    print('----------------------------------')
    all_word2 = find_second_word_pos(input_word1).word.tolist()
    if input_word1 == 'tares':
        all_word2 += ['chino']
    elif input_word1 == 'notes':
        all_word2 += ['acrid']
    elif input_word1 == 'senor':
        all_word2 += ['ducat']
    elif input_word1 == 'resin':
        all_word2 += ['loath']
    print(all_word2)
# Out:
# ----------------------------------
# notes
# ----------------------------------
# ['daily', 'gaily', 'dairy', 'fairy', 'acrid']
# ----------------------------------
# pares
# ----------------------------------
# ['doily', 'gouty', 'noily', 'doilt']
# ----------------------------------
# tares
# ----------------------------------
# ['doily', 'poind', 'noily', 'piony', 'chino']
# ----------------------------------
# canes
# ----------------------------------
# ['doily', 'roily', 'pouty', 'gouty']
# ----------------------------------
# dares
# ----------------------------------
# ['pouty', 'gouty', 'noily', 'point']
# ----------------------------------
# senor
# ----------------------------------
# ['laity', 'daily', 'gaily', 'haily', 'ducat']
# ----------------------------------
# resin
# ----------------------------------
# ['coaly', 'goaty', 'coady', 'toady', 'loath']

# %%
df_pos_lf_double = pd.DataFrame()
for input_word1 in ['notes', 'pares', 'tares', 'canes', 'dares', 'senor', 'resin']:
    print('----------------------------------')
    print(input_word1)
    print('----------------------------------')
    all_word2 = find_second_word_pos(input_word1).word.tolist()
    if input_word1 == 'tares':
        all_word2 += ['chino']
    elif input_word1 == 'notes':
        all_word2 += ['acrid']
    elif input_word1 == 'senor':
        all_word2 += ['ducat']
    elif input_word1 == 'resin':
        all_word2 += ['loath']
    print(all_word2)

    for input_word2 in all_word2:
        print(f'[---- {input_word1}, {input_word2} ----]')
        res, _ = pos_lf_strategy_double(input_word1, input_word2)
        df_pos_lf_double = df_pos_lf_double.append(res)
        print()
    print()
    print()
    print()
# Out:
# ----------------------------------
# notes
# ----------------------------------
# ['daily', 'gaily', 'dairy', 'fairy', 'acrid']
# [---- notes, daily ----]
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=5)]: Done 377 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=5)]: Done 1017 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=5)]: Done 1913 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=5)]: Done 2306 out of 2315 | elapsed:   21.7s remaining:    0.1s
# [Parallel(n_jobs=5)]: Done 2315 out of 2315 | elapsed:   21.7s finished
#     count      mean       std  min  25%  50%  75%   max  word1  word2  \
# 0  2315.0  4.806479  1.312348  2.0  4.0  5.0  5.0  11.0  notes  daily
#
#    iter_2_or_less    iter_3    iter_4    iter_5    iter_6      fail
# 0        0.000432  0.128726  0.333909  0.302376  0.130022  0.104536
# ...

# %%
df_pos_lf_double.to_csv('pos_lf_double.csv', index=False)

# %%
df_pos_lf_double = df_pos_lf_double.reset_index(drop=True)
df_pos_lf_double['words'] = df_pos_lf_double.word1 + ', ' + df_pos_lf_double.word2

# %%
df_pos_lf_double[['words', 'mean', 'iter_2_or_less', 'iter_3', 'iter_4', 'iter_5', 'iter_6', 'fail']] \
    .sort_values('mean') \
    .rename(columns={'words': 'Words', 'mean': 'Average Turns to Solve',
                    'iter_2_or_less': '% <=2 Turns', 'iter_3': '% 3 Turns',
                    'iter_4': '% 4 Turns', 'iter_5': '% 5 Turns',
                    'iter_6': '% 6 Turns', 'fail': '% Failed to Solve'})
# Out:
#            Words  Average Turns to Solve  % <=2 Turns  % 3 Turns  % 4 Turns  \
# 8   pares, doilt                4.622894     0.000000   0.152916   0.369762
# 10  tares, poind                4.641469     0.000000   0.153780   0.364147
# 21  dares, point                4.643629     0.000432   0.154212   0.366307
# 4   notes, acrid                4.718790     0.000432   0.146436   0.351620
# 26  senor, ducat                4.725270     0.000000   0.136933   0.357667
# 13  tares, chino                4.735205     0.000000   0.158099   0.333477
# 9   tares, doily                4.760259     0.000000   0.142549   0.337365
# 16  canes, pouty                4.768035     0.000432   0.130454   0.342981
# 12  tares, piony                4.770626     0.000000   0.150324   0.316631
# 11  tares, noily                4.781425     0.000000   0.145572   0.337365
# 31  resin, loath                4.784017     0.000864   0.129590   0.351620
# ...

# %%
G = '#27DDCB'
P = '#7B73F0'
palette = [
    G,G,G,P,P,P,G,G,G,G,P,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G,G
]
plt.figure(figsize=(12, 9))
sns.barplot(x='mean', y='words', data=df_pos_lf_double.sort_values('mean'), palette=palette)
plt.title('Average Turns Required for Solution', fontdict={'fontsize': 15})
plt.xlabel('Average No. of Turns')
plt.xlim(4, 5)

from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#7B73F0', edgecolor='#7B73F0', label='Wired.com'),
    Patch(facecolor='#27DDCB', edgecolor='#27DDCB', label='Global LF')]

for i, row in df_pos_lf_double.sort_values('mean', ascending=True).reset_index(drop=True).iterrows():
    plt.text(row['mean']+0.01, i+0.2, f"{row['mean']:.2f}")
plt.legend(handles=legend_elements)
plt.show()

# %% [markdown]
# ## Word Popularity

# %% [markdown]
# ### Popular Words

# %%
words_all = pd.read_table('data/archive/en_words_1_5-5.txt', delimiter=' ', header=None, index_col=None,
                         names=['word_len', 'word_freq', 'n_articles']).reset_index()
words_all = words_all.rename(columns={'index': 'word'})

# Filter by english
alphabet = list('abcdefghijklmnopqrstuvwxyz')
words_all = words_all.loc[words_all.word.apply(lambda x: all([l in alphabet for l in x]))].reset_index(drop=True)

# At least 100
words_all = words_all.loc[words_all.word_freq.ge(100)]

# %%
# Merge additional data
wordle_pop = wordle.merge(words_all[['word', 'word_freq', 'n_articles']], how='left', left_on='word', right_on='word')
wordle_pop = wordle_pop.fillna(0)

global_scores_pop = global_scores.merge(words_all[['word', 'word_freq', 'n_articles']], how='left', left_on='word', right_on='word')
global_scores_pop = global_scores_pop.fillna(0).sort_values(['score', 'word_freq'], ascending=False)

pos_lf_scores_pop = pos_lf_scores.merge(words_all[['word', 'word_freq', 'n_articles']], how='left', left_on='word', right_on='word')
pos_lf_scores_pop = pos_lf_scores_pop.fillna(0).sort_values(['score', 'word_freq'], ascending=False)

# %% [markdown]
# ### Global Single

# %%
top_singles = global_scores_pop \
    .sort_values(['score', 'word_freq'], ascending=False) \
    .groupby('score') \
    .first() \
    .sort_index(ascending=False).head(10).word.tolist()
top_singles += ['notes', 'resin', 'tares', 'senor']
print(top_singles)
# Out:
# ['arose', 'raise', 'aloes', 'laser', 'stoae', 'rates', 'aisle', 'aeons', 'snare', 'anise', 'notes', 'resin', 'tares', 'senor']

# %%
def sim_wordle_pop(input_word, solution):
    feedback = ''
    wordset = wordle_pop.copy()
    tested_words = []
    n_iter = 1

    while feedback != 'GGGGG':

        # Check solution
        feedback = get_feedback(input_word, solution)
        tested_words.append(input_word)

        # Filter wordset
        wordset = filter_wordset(input_word, feedback, wordset)
        wordset = wordset.loc[~wordset.word.isin(tested_words)]

        # Compute letter distribution of updated wordset
        wordset_letterdist = compute_letter_frequencies(wordset)
        freqs = wordset_letterdist.sum().to_dict()

        # Obtain scores
        scores = wordset.word.apply(compute_score, freqs=freqs)
        scores = pd.DataFrame({'word': wordset.word, 'score': scores, 'word_freq': wordset.word_freq}) \
            .sort_values(['score', 'word_freq'], ascending=False)

        # Set new input word
        if scores.shape[0] > 0:
            input_word = scores.word.iloc[0]
            n_iter += 1
    return n_iter

# %%
def global_lf_strategy_pop(input_word):
    results = Parallel(n_jobs=5, verbose=3)(delayed(sim_wordle_pop)(input_word, s) for s in wordle_answers.word)
    performance = pd.Series(results)
    
    results = pd.DataFrame(performance.describe()).T
    results['word'] = input_word
    results['iter_2_or_less'] = np.mean(performance <= 2)
    results['iter_3'] = np.mean(performance == 3)
    results['iter_4'] = np.mean(performance == 4)
    results['iter_5'] = np.mean(performance == 5)
    results['iter_6'] = np.mean(performance == 6)
    results['fail'] = np.mean(performance > 6)
    display(results)
    
    return results, performance

# %%
df_global_lf_pop = pd.DataFrame()
# detailed_runs = wordle_answers[['word']]
for input_word in top_singles:
    print('--------------------')
    print(input_word)
    print('--------------------')
    res, _ = global_lf_strategy_pop(input_word)
    df_global_lf_pop = df_global_lf_pop.append(res)
    print()
    print()
    print()
# Out:
# --------------------
# arose
# --------------------
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=5)]: Done 201 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=5)]: Done 521 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=5)]: Done 969 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=5)]: Done 1545 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=5)]: Done 2249 tasks      | elapsed:   46.2s
# [Parallel(n_jobs=5)]: Done 2315 out of 2315 | elapsed:   47.6s finished
#     count      mean       std  min  25%  50%  75%   max   word  \
# 0  2315.0  4.302376  1.217905  1.0  4.0  4.0  5.0  12.0  arose
#
#    iter_2_or_less    iter_3    iter_4    iter_5    iter_6     fail
# 0        0.022894  0.221598  0.401296  0.218575  0.087257  0.04838
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# --------------------
# raise
# --------------------
# ...

# %%
df_global_lf_pop[['word', 'mean', 'iter_2_or_less', 'iter_3', 'iter_4', 'iter_5', 'iter_6', 'fail']] \
    .sort_values('mean') \
    .rename(columns={'word': 'Word', 'mean': 'Average Turns to Solve',
                    'iter_2_or_less': '% <=2 Turns', 'iter_3': '% 3 Turns',
                    'iter_4': '% 4 Turns', 'iter_5': '% 5 Turns',
                    'iter_6': '% 6 Turns', 'fail': '% Failed to Solve'})
# Out:
#     Word  Average Turns to Solve  % <=2 Turns  % 3 Turns  % 4 Turns  \
# 0  tares                4.200864     0.021166   0.248380   0.415551
# 0  rates                4.228942     0.020734   0.239309   0.414255
# 0  snare                4.246220     0.027646   0.238013   0.400432
# 0  raise                4.266523     0.026782   0.236285   0.386177
# 0  notes                4.272570     0.017711   0.227646   0.415983
# 0  anise                4.279482     0.025054   0.230670   0.400864
# 0  aisle                4.282937     0.020734   0.236285   0.393952
# 0  aloes                4.286825     0.017279   0.229374   0.412095
# 0  senor                4.295896     0.024190   0.221166   0.404752
# 0  stoae                4.296328     0.021598   0.216415   0.409935
# 0  resin                4.300648     0.022030   0.217279   0.413823
# 0  arose                4.302376     0.022894   0.221598   0.401296
# 0  aeons                4.311447     0.017711   0.220302   0.421598
# ...

# %%
palette = [P,G,G,G,P,G,G,G,P,G,P,G,G,G]
plt.figure(figsize=(12, 6))
sns.barplot(x='mean', y='word', data=df_global_lf_pop.sort_values('mean'),
            palette=palette)
plt.title('Average Turns Required for Solution', fontdict={'fontsize': 15})
plt.xlabel('Average No. of Turns')
plt.xlim(4, 4.5)

from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#7B73F0', edgecolor='#7B73F0', label='Wired.com'),
    Patch(facecolor='#27DDCB', edgecolor='#27DDCB', label='Global LF')]

for i, row in df_global_lf_pop.sort_values('mean', ascending=True).reset_index(drop=True).iterrows():
    plt.text(row['mean']+0.01, i+0.2, f"{row['mean']:.2f}")
plt.legend(handles=legend_elements)
plt.show()

# %% [markdown]
# ### Global Double

# %%
def sim_wordle_double_pop(input_word1, input_word2, solution):
    feedback = ''
    wordset = wordle_pop.copy()
    tested_words = []
    n_iter = 1
    
    input_word = input_word1

    while feedback != 'GGGGG':

        # Check solution
        feedback = get_feedback(input_word, solution)
        tested_words.append(input_word)
        # print(f'[{n_iter}] Input: {input_word} | Feedback: {feedback}')

        # Filter wordset
        wordset = filter_wordset(input_word, feedback, wordset)
        wordset = wordset.loc[~wordset.word.isin(tested_words)]

        # Compute letter frequencies of updated wordset
        wordset_letterdist = compute_letter_frequencies(wordset)
        freqs = wordset_letterdist.sum().to_dict()

        # Obtain scores
        scores = wordset.word.apply(compute_score, freqs=freqs)
        scores = pd.DataFrame({'word': wordset.word, 'score': scores, 'word_freq': wordset.word_freq}) \
            .sort_values(['score', 'word_freq'], ascending=False)
        # display(scores.head(10))

        # Set new input word
        if scores.shape[0] > 0:
            if len(tested_words) < 2:
                input_word = input_word2
            else:
                input_word = scores.word.iloc[0]
            n_iter += 1
    return n_iter

# %%
def find_second_word_pop(word, two_vowel=True):
    letters = list(word)
    candidates = global_scores_pop.loc[global_scores_pop.word.apply(lambda x: all([l not in letters for l in x]))]
    candidates = candidates.loc[candidates.word.apply(lambda x: len(x) == len(set(x)))]
    if two_vowel:
        candidates = candidates.loc[
            candidates.word.apply(lambda x: x.count('a') + x.count('e') + \
                                  x.count('i') + x.count('o') + x.count('u') >= 2)
        ]
    candidates = candidates.groupby('score').first().sort_index(ascending=False)
    return candidates.head(5)

# %%
def global_lf_strategy_double_pop(input_word1, input_word2):
    results = Parallel(n_jobs=5, verbose=3)(delayed(sim_wordle_double_pop)(input_word1, input_word2, s) for s in wordle_answers.word)
    performance = pd.Series(results)
    
    results = pd.DataFrame(performance.describe()).T
    results['word1'] = input_word1
    results['word2'] = input_word2
    results['iter_2_or_less'] = np.mean(performance <= 2)
    results['iter_3'] = np.mean(performance == 3)
    results['iter_4'] = np.mean(performance == 4)
    results['iter_5'] = np.mean(performance == 5)
    results['iter_6'] = np.mean(performance == 6)
    results['fail'] = np.mean(performance > 6)
    display(results)
    
    return results, performance

# %%
for input_word1 in ['tares', 'rates', 'snare', 'raise', 'notes']:
    print('----------------------------------')
    print(input_word1)
    print('----------------------------------')
    all_word2 = find_second_word(input_word1).word.tolist()
    if input_word1 == 'tares':
        all_word2 += ['chino']
    elif input_word1 == 'notes':
        all_word2 += ['acrid']
    elif input_word1 == 'senor':
        all_word2 += ['ducat']
    elif input_word1 == 'resin':
        all_word2 += ['loath']
    print(all_word2)
# Out:
# ----------------------------------
# tares
# ----------------------------------
# ['indol', 'noily', 'colin', 'oculi', 'login', 'chino']
# ----------------------------------
# rates
# ----------------------------------
# ['indol', 'noily', 'colin', 'oculi', 'login']
# ----------------------------------
# snare
# ----------------------------------
# ['doilt', 'lotic', 'pilot', 'thiol', 'oculi']
# ----------------------------------
# raise
# ----------------------------------
# ['nould', 'donut', 'clout', 'pluto', 'moult']
# ----------------------------------
# notes
# ----------------------------------
# ['urial', 'laird', 'lairy', 'pilar', 'armil', 'acrid']

# %%
df_global_lf_double_pop = pd.DataFrame()
for input_word1 in ['tares', 'rates', 'snare', 'raise', 'notes', 'senor', 'resin']:
    print('----------------------------------')
    print(input_word1)
    print('----------------------------------')
    all_word2 = find_second_word_pop(input_word1).word.tolist()
    if input_word1 == 'tares':
        all_word2 += ['chino']
    elif input_word1 == 'notes':
        all_word2 += ['acrid']
    elif input_word1 == 'senor':
        all_word2 += ['ducat']
    elif input_word1 == 'resin':
        all_word2 += ['loath']
    print(all_word2)

    for input_word2 in all_word2:
        print(f'[---- {input_word1}, {input_word2} ----]')
        res, _ = global_lf_strategy_double_pop(input_word1, input_word2)
        df_global_lf_double_pop = df_global_lf_double_pop.append(res)
# Out:
# ----------------------------------
# tares
# ----------------------------------
# ['indol', 'noily', 'colin', 'oculi', 'login', 'chino']
# [---- tares, indol ----]
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=5)]: Done 201 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=5)]: Done 521 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=5)]: Done 969 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=5)]: Done 1545 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=5)]: Done 2249 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=5)]: Done 2315 out of 2315 | elapsed:   48.5s finished
#     count      mean       std  min  25%  50%  75%   max  word1  word2  \
# 0  2315.0  4.193089  1.033302  3.0  4.0  4.0  5.0  10.0  tares  indol
#
#    iter_2_or_less   iter_3    iter_4    iter_5    iter_6      fail
# 0             0.0  0.24838  0.447948  0.212527  0.061339  0.029806
# ...

# %%
df_global_lf_double_pop.to_csv('global_lf_double_pop.csv', index=False)

# %%
df_global_lf_double_pop = df_global_lf_double_pop.reset_index(drop=True)
df_global_lf_double_pop['words'] = df_global_lf_double_pop.word1 + ', ' + df_global_lf_double_pop.word2

# %%
df_global_lf_double_pop[['words', 'mean', 'iter_2_or_less', 'iter_3', 'iter_4', 'iter_5', 'iter_6', 'fail']] \
    .sort_values('mean') \
    .rename(columns={'words': 'Words', 'mean': 'Average Turns to Solve',
                    'iter_2_or_less': '% <=2 Turns', 'iter_3': '% 3 Turns',
                    'iter_4': '% 4 Turns', 'iter_5': '% 5 Turns',
                    'iter_6': '% 6 Turns', 'fail': '% Failed to Solve'})
# Out:
#            Words  Average Turns to Solve  % <=2 Turns  % 3 Turns  % 4 Turns  \
# 11  snare, doilt                4.138229     0.000432   0.293305   0.422030
# 2   tares, colin                4.153780     0.000000   0.280346   0.424190
# 13  snare, pilot                4.158099     0.000864   0.274730   0.438445
# 30  senor, plait                4.160691     0.000432   0.275594   0.432829
# 14  snare, thiol                4.165875     0.000432   0.286825   0.410799
# 27  senor, tidal                4.170194     0.000432   0.263067   0.443629
# 8   rates, colin                4.174082     0.000000   0.269978   0.428942
# 35  resin, ploat                4.176674     0.000432   0.256156   0.439309
# 31  senor, laith                4.177538     0.000000   0.270842   0.422462
# 5   tares, chino                4.179698     0.000000   0.279050   0.406911
# 18  raise, clout                4.187473     0.000864   0.275594   0.412095
# ...

# %%
palette = [G,G,G,G,G,G,G,G,G,P,G,G,P,G,G,G,G,G,G,G,G,G,G,P,G,G,G,G,G,P,G,G,G,G,G,G,G,G,G]
plt.figure(figsize=(12, 9))
sns.barplot(x='mean', y='words', data=df_global_lf_double_pop.sort_values('mean'), palette=palette)
plt.title('Average Turns Required for Solution', fontdict={'fontsize': 15})
plt.xlabel('Average No. of Turns')
plt.xlim(4, 4.6)

from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#7B73F0', edgecolor='#7B73F0', label='Wired.com'),
    Patch(facecolor='#27DDCB', edgecolor='#27DDCB', label='Global LF')]

for i, row in df_global_lf_double_pop.sort_values('mean', ascending=True).reset_index(drop=True).iterrows():
    plt.text(row['mean']+0.01, i+0.2, f"{row['mean']:.2f}")
plt.legend(handles=legend_elements)
plt.show()
