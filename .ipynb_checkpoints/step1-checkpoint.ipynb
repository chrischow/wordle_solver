# %% [markdown]
# # Step 1: Filter Away

# %% [markdown]
# ## Imports

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from joblib import Parallel, delayed

sns.set()
P = '#7B73F0'
G = '#27DDCB'

# %% [markdown]
# ## Load Words

# %%
with open('data/wordle-candidates.json', 'r') as file:
    wordle_candidates = json.load(file)
    
with open('data/wordle-answers.json', 'r') as file:
    wordle_answers = json.load(file)

wordle_candidates = pd.DataFrame(wordle_candidates['words'], columns=['word'])
wordle_answers = pd.DataFrame(wordle_answers['words'], columns=['word'])
wordle_candidates['is_answer'] = 0
wordle_answers['is_answer'] = 1
wordle = wordle_candidates.append(wordle_answers).reset_index(drop=True)

# %% [markdown]
# ## Game Logic

# %%
def get_feedback(input_word, solution):
    output = ''
    for i in range(5):
        if input_word[i] == solution[i]:
            output += 'G'
        elif input_word[i] in solution:
            output += 'Y'
        else:
            output += 'X'
    return output

# %%
def filter_wordset(input_word, feedback, wordset):
    newset = wordset.copy()
    for i in range(5):
        if feedback[i] == 'G':
            newset = newset.loc[newset.word.str[i] == input_word[i]]
        elif feedback[i] == 'Y':
            # newset = newset.loc[newset.word.str.contains(input_word[i])]
            newset = newset.loc[newset.word.str.contains(input_word[i]) & newset.word.apply(lambda x: x[i] != input_word[i])]
        else:
            newset = newset.loc[~newset.word.str.contains(input_word[i])]
    return newset

# %% [markdown]
# ## Metrics

# %%
def update_space(candidate_word, fb, space):
    s = space.copy()
    for i, l in enumerate(candidate_word):
        row = alpha_dict[l]
        # Green: all zeros except cell
        if fb[i] == 'G':
            s[:, i] = 0
            s[row, i] = 1
        elif fb[i] == 'X':
            s[row, :] = 0
        elif fb[i] == 'Y':
            s[row, i] = 0
    return s

# %%
def calc_improvement(candidate_word, solution_word):
    fb = get_feedback(candidate_word, solution_word)
    space = np.ones((26,5))
    curr_score = 1.0
    updated_space = update_space(candidate_word, fb, space)
    new_score = updated_space.mean()
    return curr_score - new_score

# %%
alpha_dict = {l:i  for i, l in enumerate(list('abcdefghijklmnopqrstuvwxyz'))}

# %% [markdown]
# ## Global Letter Frequency

# %% [markdown]
# ### FN: Compute global LFs and word scores

# %%
def compute_letter_frequencies(wordset):
    w = wordset.copy()
    for letter in list('abcdefghijklmnopqrstuvwxyz'):
        w[letter] = w.word.str.contains(letter).astype(int)
    return w.iloc[:, 1:]

def compute_score(x, freqs):
    letters = set(x)
    output = 0
    for letter in letters:
        output += freqs[letter]
    return output

# %% [markdown]
# ### Compute global scores

# %%
global_freqs = compute_letter_frequencies(wordle).sum().to_dict()
global_scores = wordle.word.apply(compute_score, freqs=global_freqs)
global_scores = pd.DataFrame({'word': wordle.word, 'score': global_scores}).sort_values('score', ascending=False)

compute_letter_frequencies(wordle).sum().sort_values().plot.barh(color=P, figsize=(12,6))
plt.title('Global Letter Frequencies', fontdict={'fontsize': 15})
plt.show()

plot_words = global_scores.head(10).reset_index(drop=True)
plot_words.set_index('word').plot.barh(color=P, figsize=(12,6), legend=None)
plt.gca().invert_yaxis()
plt.title('Scores for 13k 5-letter Words', fontdict={'fontsize': 15})
for i, row in plot_words.iterrows():
    plt.text(row.score+100, i+0.1, row.score)
plt.show()

# %%
def compute_n_filtered(input_word, solution):
    feedback = get_feedback(input_word, solution)
    candidates = filter_wordset(input_word, feedback, wordle)
    return input_word, solution, candidates.shape[0], feedback.count('G'), feedback.count('Y'), feedback.count('X')

# %%
lf_n_filtered = Parallel(n_jobs=5, verbose=1)(delayed(compute_n_filtered)(input_word, solution) \
                                              for input_word in global_scores.word.head(500) \
                                              for solution in wordle_answers.word)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  65 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=5)]: Done 2325 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=5)]: Done 6325 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=5)]: Done 11925 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=5)]: Done 19125 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=5)]: Done 27925 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=5)]: Done 38325 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=5)]: Done 50325 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=5)]: Done 63925 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=5)]: Done 79125 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=5)]: Done 95925 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=5)]: Done 114325 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=5)]: Done 134325 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=5)]: Done 155925 tasks      | elapsed:  8.3min
# ...

# %%
df_lf_n_filtered = pd.DataFrame(lf_n_filtered, columns=['word', 'solution', 'n_candidates', 'g', 'y', 'x'])
df_lf_n_filtered['decrease'] = 1 - df_lf_n_filtered['n_candidates'] / 12972
df_lf_n_filtered['space_improvement'] = df_lf_n_filtered[['word', 'solution']].apply(lambda row: calc_improvement(row.word, row.solution), axis=1)

# %%
df_lf_n_filtered.to_csv('results/step1_lf.csv', index=False)

# %%
results = df_lf_n_filtered.groupby('word')[['decrease', 'space_improvement']].mean()
results = results.merge(global_scores, how='left', on='word')

# %%
results.sort_values('decrease', ascending=False).head(20)
# Out:
#       word  decrease  space_improvement  score
# 397  soare  0.978831           0.245669  24791
# 159  lares  0.978574           0.202186  23994
# 262  rales  0.978258           0.199811  23994
# 31   arles  0.978113           0.199595  23994
# 453  tares  0.978098           0.206343  23913
# 271  reais  0.977744           0.197913  24469
# 266  rates  0.977445           0.199545  23913
# 258  raise  0.977362           0.227785  24469
# 206  nares  0.977323           0.199781  23667
# 9    aeros  0.977154           0.188005  24791
# 333  saner  0.976447           0.233830  23667
# 274  reals  0.976323           0.198485  23994
# 450  tales  0.976049           0.204662  23118
# 168  lears  0.975967           0.196694  23994
# 18   aloes  0.975959           0.206207  23996
# 361  serai  0.975733           0.204635  24469
# 467  teras  0.975572           0.191115  23913
# 462  tears  0.975517           0.200804  23913
# 327  salet  0.975465           0.235594  23118
# ...

# %%
results[['decrease', 'space_improvement', 'score']].corr()
# Out:
#                    decrease  space_improvement     score
# decrease           1.000000           0.232090  0.626674
# space_improvement  0.232090           1.000000  0.072211
# score              0.626674           0.072211  1.000000

# %% [markdown]
# ## Positional Letter Frequency - Sum

# %%
def compute_pos_letter_freq(wordset):
    pos_scores = {}
    pos_scores[0] = wordset.word.str[0].value_counts().to_dict()
    pos_scores[1] = wordset.word.str[1].value_counts().to_dict()
    pos_scores[2] = wordset.word.str[2].value_counts().to_dict()
    pos_scores[3] = wordset.word.str[3].value_counts().to_dict()
    pos_scores[4] = wordset.word.str[4].value_counts().to_dict()
    
    return pos_scores

# %%
def compute_pos_score(letters, pos_scores):
    output = 0
    for i, letter in enumerate(letters):
        output += pos_scores[i].get(letter, 0)
    return output

# %%
pos_scores = compute_pos_letter_freq(wordle)
pos_lf_scores = wordle.word.apply(compute_pos_score, pos_scores=pos_scores)
pos_lf_scores = pd.DataFrame({'word': wordle.word, 'score': pos_lf_scores}).sort_values('score', ascending=False)
pos_df = pd.DataFrame(pos_scores.values()).T

# %%
for i in range(5):
    pos_df = pd.DataFrame(pos_scores.values()).T.sort_values(i, ascending=False)
    pos_df[i].plot.barh(color='#7B73F0', figsize=(12,8))

    for j, row in pos_df.reset_index().iterrows():
        plt.text(row[i]+10, j+0.2, row[i], fontsize=10)

    plt.gca().invert_yaxis()
    plt.title(f'Letter Frequency at Position {i+1}', fontdict={'fontsize': 15})
    plt.show()

# %%
plf_n_filtered = Parallel(n_jobs=5, verbose=1)(delayed(compute_n_filtered)(input_word, solution) \
                                               for input_word in pos_lf_scores.word.head(100) \
                                               for solution in wordle_answers.word)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done 150 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=5)]: Done 2550 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=5)]: Done 6550 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=5)]: Done 12150 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=5)]: Done 19350 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=5)]: Done 28150 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=5)]: Done 38550 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=5)]: Done 50550 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=5)]: Done 64150 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=5)]: Done 79350 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=5)]: Done 96150 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=5)]: Done 114550 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=5)]: Done 134550 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=5)]: Done 156150 tasks      | elapsed:  8.0min
# ...

# %%
df_plf_n_filtered = pd.DataFrame(plf_n_filtered, columns=['word', 'solution', 'n_candidates', 'g', 'y', 'x'])
df_plf_n_filtered['decrease'] = 1 - df_plf_n_filtered['n_candidates'] / 12972
df_plf_n_filtered['space_improvement'] = df_plf_n_filtered[['word', 'solution']].apply(lambda row: calc_improvement(row.word, row.solution), axis=1)

# %%
df_plf_n_filtered.to_csv('results/step1_plf.csv', index=False)

# %%
results_plf = df_plf_n_filtered.groupby('word')[['decrease', 'space_improvement']].mean()
results_plf = results_plf.merge(pos_lf_scores, how='left', on='word')

# %%
results_plf.sort_values('decrease', ascending=False).head(20)
# Out:
#      word  decrease  space_improvement  score
# 39  lares  0.978574           0.202186  10323
# 56  rales  0.978258           0.199811  10024
# 90  tares  0.978098           0.206343  10561
# 46  nares  0.977323           0.199781  10071
# 88  tales  0.976049           0.204662  10211
# 13  cares  0.975003           0.212497  10668
# 38  lanes  0.974961           0.203788  10089
# 40  lores  0.974868           0.203496  10156
# 22  dares  0.973773           0.207187  10431
# 96  tores  0.973764           0.207609  10394
# 34  hares  0.973231           0.204137  10235
# 58  rones  0.972536           0.204170   9973
# 94  toles  0.972145           0.205878  10044
# 49  pares  0.972124           0.209786  10605
# 43  mares  0.971989           0.207862  10439
# 30  gares  0.971959           0.208423  10384
# 15  cates  0.971580           0.210517  10086
# 21  dales  0.971017           0.205665  10081
# 12  canes  0.970929           0.213972  10434
# ...

# %%
results_plf[['decrease', 'space_improvement', 'score']].corr()
# Out:
#                    decrease  space_improvement     score
# decrease           1.000000           0.745697 -0.009216
# space_improvement  0.745697           1.000000  0.033206
# score             -0.009216           0.033206  1.000000

# %% [markdown]
# ## Combined List

# %%
results['glf'] = 1
results_plf['plf'] = 1
all_results = results.append(results_plf, ignore_index=True)
all_results = all_results.groupby('word').agg({
    'decrease': lambda x: x.iloc[0],
    'space_improvement': lambda x: x.iloc[0],
    'glf': lambda x: x.sum(),
    'plf': lambda x: x.sum()
}).sort_values('decrease', ascending=False).reset_index()

# %%
all_results.iloc[:100][['glf', 'plf']].sum()
# Out:
# glf    83.0
# plf    25.0
# dtype: float64

# %%
all_results.iloc[:100].to_csv('results/step1_combined.csv', index=False)

# %%
all_results.iloc[:100]
# Out:
#      word  decrease  space_improvement  glf  plf
# 0   soare  0.978831           0.245669  1.0  0.0
# 1   lares  0.978574           0.202186  1.0  1.0
# 2   rales  0.978258           0.199811  1.0  1.0
# 3   arles  0.978113           0.199595  1.0  0.0
# 4   tares  0.978098           0.206343  1.0  1.0
# 5   reais  0.977744           0.197913  1.0  0.0
# 6   rates  0.977445           0.199545  1.0  0.0
# 7   raise  0.977362           0.227785  1.0  0.0
# 8   nares  0.977323           0.199781  1.0  1.0
# 9   aeros  0.977154           0.188005  1.0  0.0
# 10  saner  0.976447           0.233830  1.0  0.0
# 11  reals  0.976323           0.198485  1.0  0.0
# 12  tales  0.976049           0.204662  1.0  1.0
# 13  lears  0.975967           0.196694  1.0  0.0
# 14  aloes  0.975959           0.206207  1.0  0.0
# 15  serai  0.975733           0.204635  1.0  0.0
# 16  teras  0.975572           0.191115  1.0  0.0
# 17  tears  0.975517           0.200804  1.0  0.0
# ...
