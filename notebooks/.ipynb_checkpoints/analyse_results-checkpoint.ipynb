# %% [markdown]
# # Analyse Results

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

sns.set()
plt.style.use('ggplot')
fontdict = {'fontsize': 15}

# %% [markdown]
# ## Load Data

# %%
words = ['arles', 'arose', 'dares', 'lares', 'lores', 'nares',
        'raile', 'raise', 'rales', 'rates', 'reais', 'roate',
        'soare', 'stare', 'tales', 'tares', 'tores']

algos = ['lf', 'gyx', 'lf-pop', 'gyx-pop']

# %%
df = pd.DataFrame()
all_data = pd.DataFrame()

for algo in algos:
    print(f'Loading {algo}...')
    for word in words:
        download_path = f'../kernel_output/{algo}/'
        if algo == 'gyx':
            algo_correct = 'expected_gyx'
        elif algo == 'lf-pop':
            algo_correct = 'lf'
        elif algo == 'gyx-pop':
            algo_correct = 'expected_gyx'
        else:
            algo_correct = algo
        filename = f"wordlebot-{algo_correct}-{word}.csv"
        
        if filename in os.listdir(download_path):
            temp_df = pd.read_csv(f'{download_path}{filename}')
            temp_df['algo'] = algo
            all_data = all_data.append(temp_df)
            with open(f"{download_path}wordlebot-{algo}-{word}.log") as f:
                temp_log = f.readlines()
            runtime = pd.DataFrame(eval(''.join(temp_log))).time.iloc[-1]
            temp_results = pd.DataFrame([{
                'Seed Word': word,
                'Ranking Algorithm': algo,
                # 'Runtime': runtime,
                'Mean Steps': temp_df.steps.mean(),
                'Success Rate': temp_df.steps.le(6).mean(),
                '3-Steps or Less': temp_df.steps.le(3).mean(),
                'Worst Case': temp_df.steps.max()
            }])
            
            df = df.append(temp_results)

print('Loading ncands...')
for word in words:
    data_path = '../results'
    filename = f'wordlebot_{word}.csv'
    if filename in os.listdir(data_path):
        temp_df = pd.read_csv(f'{data_path}/{filename}')
        temp_df['algo'] = 'ncands'
        all_data = all_data.append(temp_df)
        temp_results = pd.DataFrame([{
            'Seed Word': word,
            'Ranking Algorithm': 'ncands',
            # 'Runtime': runtime,
            'Mean Steps': temp_df.steps.mean(),
            'Success Rate': temp_df.steps.le(6).mean(),
            '3-Steps or Less': temp_df.steps.le(3).mean(),
            'Worst Case': temp_df.steps.max()
        }])
        df = df.append(temp_results)
        
print('Loading entropy...')
for word in words:
    data_path = '../results'
    filename = f'wordlebot-entropy-{word}.csv'
    if filename in os.listdir(data_path):
        temp_df = pd.read_csv(f'{data_path}/{filename}')
        temp_df['algo'] = 'entropy'
        all_data = all_data.append(temp_df)
        temp_results = pd.DataFrame([{
            'Seed Word': word,
            'Ranking Algorithm': 'entropy',
            # 'Runtime': runtime,
            'Mean Steps': temp_df.steps.mean(),
            'Success Rate': temp_df.steps.le(6).mean(),
            '3-Steps or Less': temp_df.steps.le(3).mean(),
            'Worst Case': temp_df.steps.max()
        }])
        df = df.append(temp_results)
# Out:
# Loading lf...
# Loading gyx...
# Loading lf-pop...
# Loading gyx-pop...
# Loading ncands...
# Loading entropy...

# %% [markdown]
# ## Compute Ranking

# %%
metrics = ['Mean Steps', 'Success Rate', '3-Steps or Less']
ascs = [True, False, False]
for metric in metrics:
    x = df[metric]
    df[f'{metric}_score'] = (x - x.min()) / (x.max() - x.min())
    if metric == 'Mean Steps':
        df[f'{metric}_score'] = 1 - df[f'{metric}_score']

df['avg_score'] = df[[f'{s}_score' for s in metrics]].mean(axis=1)

# %% [markdown]
# ### Raw Ranking

# %%
for metric, asc in zip(metrics, ascs):

    print(f'\nBy {metric}:')
    display(df.sort_values(metric, ascending=asc).head(8))
    
print('\nBy Average Score:')
display(df.sort_values('avg_score', ascending=False).head(8))
# Out:
# By Mean Steps:
#   Seed Word Ranking Algorithm  Mean Steps  Success Rate  3-Steps or Less  \
# 0
# 94    0.163560
# 95    0.141708
# 96    0.133631
# 97    0.133586
# 98    0.101806
# 99    0.100119
# 100   0.095115
# 101   0.042424

# %% [markdown]
# ### By Ranking Algorithm

# %%
metric_order = ['entropy', 'ncands', 'lf', 'lf-pop', 'gyx', 'gyx-pop', 'entropy']
for metric, asc in zip(metrics, ascs):

    print(f'\nBy {metric}:')
    display(df.sort_values(metric, ascending=asc).groupby('Ranking Algorithm').first().loc[metric_order])
    
print('\nBy Average Score:')
display(df.sort_values('avg_score', ascending=False).groupby('Ranking Algorithm').first().loc[metric_order])
# Out:
# By Mean Steps:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# entropy               stare    3.526134      0.994384         0.532181
# ncands                tales    3.601728      0.997408         0.467387
# lf                    stare    3.728726      0.991793         0.423758
# lf-pop                tores    3.770194      0.992225         0.417279
# gyx                   stare    3.831965      0.989201         0.377538
# gyx-pop               tales    3.889849      0.987905         0.366739
# entropy               stare    3.526134      0.994384         0.532181
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# entropy                     8          1.000000            0.854545
# ncands                      8          0.851946            0.981818
# lf                          9          0.603215            0.745455
# lf-pop                      8          0.521997            0.763636
# gyx                         9          0.401015            0.636364
# gyx-pop                     9          0.287648            0.581818
# entropy                     8          1.000000            0.854545
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# entropy                         1.000000   0.951515
# ncands                          0.693878   0.842547
# lf                              0.487755   0.612142
# lf-pop                          0.457143   0.580925
# gyx                             0.269388   0.435589
# gyx-pop                         0.218367   0.362611
# entropy                         1.000000   0.951515
# By Success Rate:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# entropy               tores    3.545140      0.997408         0.516631
# ncands                tares    3.612095      0.997840         0.455724
# lf                    tales    3.749028      0.994384         0.395680
# lf-pop                tores    3.770194      0.992225         0.417279
# gyx                   tales    3.836285      0.990929         0.371058
# gyx-pop               tales    3.889849      0.987905         0.366739
# entropy               tores    3.545140      0.997408         0.516631
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# entropy                     8          0.962775            0.981818
# ncands                      8          0.831641            1.000000
# lf                          8          0.563452            0.854545
# lf-pop                      8          0.521997            0.763636
# gyx                         9          0.392555            0.709091
# gyx-pop                     9          0.287648            0.581818
# entropy                     8          0.962775            0.981818
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# entropy                         0.926531   0.957041
# ncands                          0.638776   0.823472
# lf                              0.355102   0.591033
# lf-pop                          0.457143   0.580925
# gyx                             0.238776   0.446807
# gyx-pop                         0.218367   0.362611
# entropy                         0.926531   0.957041
# By 3-Steps or Less:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# entropy               stare    3.526134      0.994384         0.532181
# ncands                raile    3.606911      0.995248         0.481210
# lf                    arose    3.739525      0.990065         0.429806
# lf-pop                arose    3.782721      0.989201         0.423326
# gyx                   roate    3.837149      0.985745         0.385745
# gyx-pop               roate    3.904968      0.980130         0.379266
# entropy               stare    3.526134      0.994384         0.532181
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# entropy                     8          1.000000            0.854545
# ncands                      8          0.841794            0.890909
# lf                          8          0.582064            0.672727
# lf-pop                      8          0.497462            0.636364
# gyx                         9          0.390863            0.490909
# gyx-pop                     9          0.258037            0.254545
# entropy                     8          1.000000            0.854545
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# entropy                         1.000000   0.951515
# ncands                          0.759184   0.830629
# lf                              0.516327   0.590373
# lf-pop                          0.485714   0.539847
# gyx                             0.308163   0.396645
# gyx-pop                         0.277551   0.263378
# entropy                         1.000000   0.951515
# By Average Score:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# entropy               tales    3.528726      0.996976         0.523542
# ncands                tales    3.601728      0.997408         0.467387
# lf                    tores    3.730022      0.991793         0.425054
# lf-pop                tores    3.770194      0.992225         0.417279
# gyx                   tales    3.836285      0.990929         0.371058
# gyx-pop               tales    3.889849      0.987905         0.366739
# entropy               tales    3.528726      0.996976         0.523542
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# entropy                     8          0.994924            0.963636
# ncands                      8          0.851946            0.981818
# lf                          8          0.600677            0.745455
# lf-pop                      8          0.521997            0.763636
# gyx                         9          0.392555            0.709091
# gyx-pop                     9          0.287648            0.581818
# entropy                     8          0.994924            0.963636
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# entropy                         0.959184   0.972581
# ncands                          0.693878   0.842547
# lf                              0.493878   0.613336
# lf-pop                          0.457143   0.580925
# gyx                             0.238776   0.446807
# gyx-pop                         0.218367   0.362611
# entropy                         0.959184   0.972581

# %% [markdown]
# ### Performance Across Algos

# %%
df['within_rank_steps'] = df.groupby(['Ranking Algorithm'])['Mean Steps'].rank()
df['within_rank_success'] = df.groupby(['Ranking Algorithm'])['Success Rate'].rank(ascending=False)
df['within_rank_3steps'] = df.groupby(['Ranking Algorithm'])['3-Steps or Less'].rank(ascending=False)
df = df.sort_values(['Seed Word', 'Ranking Algorithm'])

# %%
df.loc[df['Seed Word'].eq('tores')]
# Out:
#   Seed Word Ranking Algorithm  Mean Steps  Success Rate  3-Steps or Less  \
# 0     tores           entropy    3.545140      0.997408         0.516631
# 0     tores               gyx    3.872570      0.985745         0.368898
# 0     tores           gyx-pop    3.944276      0.978834         0.362851
# 0     tores                lf    3.730022      0.991793         0.425054
# 0     tores            lf-pop    3.770194      0.992225         0.417279
# 0     tores            ncands    3.617711      0.996976         0.462203
#
#    Worst Case  Mean Steps_score  Success Rate_score  3-Steps or Less_score  \
# 0           8          0.962775            0.981818               0.926531
# 0           9          0.321489            0.490909               0.228571
# 0           9          0.181049            0.200000               0.200000
# 0           8          0.600677            0.745455               0.493878
# 0           8          0.521997            0.763636               0.457143
# 0           8          0.820643            0.963636               0.669388
#
#    avg_score  within_rank_steps  within_rank_success  within_rank_3steps
# 0   0.957041               10.0                  1.0                11.0
# 0   0.346990                6.0                  8.0                 6.0
# 0   0.193683                7.0                 11.0                 6.0
# 0   0.613336                2.0                  4.5                 2.5
# 0   0.580925                1.0                  1.0                 4.0
# 0   0.817889                6.0                  4.0                 6.0

# %%
print('Mean Steps')
display(df.groupby('Seed Word').within_rank_steps.describe().sort_values('mean'))

print('\nSuccess Rate')
display(df.groupby('Seed Word').within_rank_success.describe().sort_values('mean'))

print('\nWithin 3 Steps')
display(df.groupby('Seed Word').within_rank_3steps.describe().sort_values('mean'))
# Out:
# Mean Steps
#            count       mean       std   min     25%    50%     75%   max
# Seed Word
# stare        6.0   1.666667  0.816497   1.0   1.000   1.50   2.000   3.0
# tares        6.0   6.000000  2.683282   4.0   4.250   5.00   6.500  11.0
# raise        6.0   6.083333  3.852488   2.0   2.875   5.50   9.250  11.0
# tales        6.0   7.166667  2.483277   5.0   5.000   6.50   9.500  10.0
# arles        6.0  10.833333  2.136976   9.0   9.000  10.50  12.000  14.0
# rates        6.0  11.166667  3.371449   8.0   8.500  11.00  12.000  17.0
# lares        6.0  12.000000  2.213594   9.5  10.250  11.75  13.625  15.0
# reais        6.0  13.416667  2.416954  11.0  11.500  13.00  14.875  17.0
# rales        6.0  13.500000  1.048809  12.0  13.000  13.50  14.000  15.0
# nares        6.0  13.666667  2.523225   9.5  12.625  14.00  15.750  16.0
# lores        6.0  15.583333  1.200694  14.0  15.000  15.25  16.625  17.0
# dares        6.0  16.000000  1.095445  14.0  16.000  16.00  16.750  17.0

# %%
(df.groupby('Seed Word').within_rank_steps.describe() + df.groupby('Seed Word').within_rank_success.describe() + df.groupby('Seed Word').within_rank_3steps.describe()).sort_values('mean') / 3
# Out:
#            count       mean       std        min        25%        50%  \
# Seed Word
# stare        6.0   4.027778  2.598275   1.333333   2.333333   3.416667
# tales        6.0   4.055556  2.081231   2.333333   2.416667   3.333333
# tares        6.0   4.888889  2.197787   2.666667   3.541667   4.333333
# tores        6.0   5.388889  3.384148   1.500000   3.083333   5.416667
# roate        6.0   5.972222  2.813255   2.833333   3.916667   5.500000
# soare        6.0   8.638889  2.893775   5.166667   6.625000   8.250000
# arles        6.0   8.694444  2.925152   5.833333   6.500000   8.166667
# raile        6.0   8.750000  3.755813   3.166667   6.500000   9.500000
# arose        6.0   8.777778  3.430644   4.000000   6.583333   9.666667
# raise        6.0   9.194444  2.945311   5.500000   6.958333   9.500000
# rates        6.0  10.055556  2.883342   7.666667   8.000000   9.333333
# rales        6.0  10.722222  1.895562   8.333333   9.458333  10.666667
# lares        6.0  10.861111  3.569609   7.166667   7.791667  10.583333
# nares        6.0  12.083333  2.565721   8.000000  11.000000  12.416667
# reais        6.0  13.111111  2.655622   9.833333  11.416667  12.750000
# lores        6.0  13.777778  2.189455  10.333333  12.791667  14.166667
# dares        6.0  14.000000  2.304393  10.333333  13.083333  14.250000
#
#                  75%        max
# Seed Word
# stare       5.375000   8.000000
# tales       5.500000   7.000000
# tares       5.750000   8.500000
# tores       6.625000  10.666667
# roate       8.208333   9.500000
# soare      11.125000  12.000000
# arles      10.333333  13.000000
# raile      11.500000  12.666667
# arose      10.875000  12.500000
# raise      11.416667  12.500000
# rates      10.791667  15.166667
# rales      12.000000  13.166667
# lares      13.500000  15.500000
# nares      13.708333  15.000000
# reais      14.833333  16.833333
# lores      15.291667  16.000000
# dares      15.666667  16.333333

# %%
df_sorted = df.sort_values('Ranking Algorithm', key=lambda x: x.replace({
    'gyx-pop': 0, 'gyx': 1, 'lf-pop': 2, 'lf': 3, 'ncands': 4, 'entropy': 5
}))

# df_sorted = df_sorted.loc[df_sorted['Seed Word'].eq('tales')] \
#     .append(df_sorted.loc[df_sorted['Seed Word'].eq('raile')]) \
#     .append(df_sorted.loc[df_sorted['Seed Word'].eq('tares')]) \
#     .append(df_sorted.loc[~df_sorted['Seed Word'].isin(['tales', 'raile', 'tares'])])

for metric in metrics:
    
    plt.figure(figsize=(11, 8), dpi=300)
    sns.boxplot(y=metric, x='Ranking Algorithm', data=df_sorted)
    plt.title(f'{metric} vs. Ranking Algorithm + Decision Rule', fontdict=fontdict)
    plt.xlabel('Ranking Algo + Decision Rule')
    ax = plt.gca()
    other_labelled = False
    for word in df['Seed Word'].unique():
        if word in ['tales', 'tares', 'tores', 'stare', 'roate']:
            lw = 1.5
            ls = 'solid'
            ms = 3
        else:
            lw = 1
            ls = 'dashed'
            ms = 2
        if word == 'tales':
            color = '#27ddcb'
            mc = '#27ddcb'
            label = word
        elif word == 'tares':
            color = '#120c6e'
            mc = '#120c6e'
            label = word
        elif word == 'tores':
            color = '#333f50'
            mc = '#333f50'
            label = word
        elif word == 'stare':
            color = '#7b73f0'
            mc = '#7b73f0'
            label = word
        elif word == 'roate':
            color = '#C3A942'
            mc = '#C3A942'
            label = word
        else:
            color = 'lightgrey'
            mc = 'darkgrey'
            if not other_labelled:
                label = 'Others'
                other_labelled = True
            else:
                label = None
        linedata = df_sorted.loc[df_sorted['Seed Word'].eq(word)].reset_index(drop=True)
            
        for i, row in linedata.iterrows():
            if i == linedata.shape[0]-1:
                break
            ax.plot([i, i+1], [row[metric], linedata[metric].iloc[i+1]],
                    linewidth=lw, linestyle=ls, color=color, marker='o',
                    markersize=ms, markerfacecolor=mc, markeredgecolor=mc, label=label)
            label = None
    ax = plt.gca()
    handles, labels = ax.get_legend_handles_labels()
    # print(handles, labels)
    ax.legend(
        [handles[k] for k in [2,3,4,5,1,0]],
        [labels[k] for k in [2,3,4,5,1,0]]
    )
    plt.savefig(f'../results/strat_{metric.lower().replace(" ", "_")}_hi-res.png')
    # plt.legend()
    plt.show()

# %% [markdown]
# ## Diagnosis

# %%
adf = all_data.drop('Unnamed: 0', axis=1)
adf['words'] = adf.words.apply(eval)
adf['word'] = adf.words.apply(lambda x: x[0])
adf['solution'] = adf.words.apply(lambda x: x[-1])
adf = adf.sort_values(['solution', 'word']).reset_index(drop=True)

# %%
solution_scores = adf.groupby('solution').agg({
    'steps': [
        ('Mean Steps', 'mean'),
        ('Success Rate', lambda x: np.mean(x < 7)),
        ('3-Steps or Less', lambda x: np.mean(x <= 3))
    ]
})

# %%
solution_scores.columns = ['Mean Steps', 'Success Rate', '3-Steps or Less']

# %%
df_low_avg_steps = solution_scores.loc[solution_scores['Mean Steps'].gt(6)].sort_values('Mean Steps', ascending=False)
df_low_avg_steps[['Mean Steps']].plot.barh(figsize=(10,7))
plt.gca().invert_yaxis()
plt.title('Solution Words with Average Steps > 6', fontdict=fontdict)
plt.show()
display(df_low_avg_steps)


df_low_success = solution_scores.loc[solution_scores['Success Rate'].lt(0.5)].sort_values('Success Rate', ascending=True)
df_low_success[['Success Rate']].plot.barh(figsize=(10,7))
plt.gca().invert_yaxis()
plt.title('Solution Words with Success Rate < 50%', fontdict=fontdict)
plt.show()
display(df_low_success)

df_zero_3step = solution_scores.loc[solution_scores['3-Steps or Less'].eq(0)].sort_values('Mean Steps', ascending=False)
df_zero_3step[['Mean Steps']].plot.barh(figsize=(10,7))
plt.gca().invert_yaxis()
plt.title('Solution Words with 3-Steps or Less Rate == 0%', fontdict=fontdict)
plt.show()
display(df_zero_3step)
# Out:
#           Mean Steps  Success Rate  3-Steps or Less
# solution
# vaunt       7.352941      0.137255         0.000000
# wound       6.852941      0.196078         0.078431
# foyer       6.323529      0.539216         0.009804
# graze       6.323529      0.568627         0.000000
# waver       6.264706      0.627451         0.000000
# goner       6.019608      0.529412         0.166667
# joker       6.019608      0.588235         0.009804
# boxer       6.009804      0.666667         0.009804
# shave       6.009804      0.460784         0.156863
#           Mean Steps  Success Rate  3-Steps or Less
# solution
# vaunt       7.352941      0.137255         0.000000
# wound       6.852941      0.196078         0.078431
# baste       5.676471      0.411765         0.333333
# shave       6.009804      0.460784         0.156863
#           Mean Steps  Success Rate  3-Steps or Less
# solution
# vaunt       7.352941      0.137255              0.0
# graze       6.323529      0.568627              0.0
# waver       6.264706      0.627451              0.0
# greed       5.401961      0.970588              0.0
# ember       5.274510      0.892157              0.0
# jazzy       5.274510      0.901961              0.0
# stave       5.235294      0.980392              0.0
# jiffy       4.990196      1.000000              0.0
# fuzzy       4.931373      0.970588              0.0
# stuff       4.901961      1.000000              0.0
# upper       4.764706      0.980392              0.0
# bezel       4.696078      0.990196              0.0
# fizzy       4.588235      1.000000              0.0
# guppy       4.509804      0.970588              0.0
# puffy       4.392157      0.980392              0.0

# %%
adf.loc[adf.word.eq('tales')].to_dict('records')[:3]
# Out:
# [{'steps': 5,
#   'words': ['tales', 'noria', 'whack', 'quack', 'aback'],
#   'feedback': "['XYXXX', 'XXXXY', 'XXGGG', 'XXGGG', 'GGGGG']",
#   'ncands': '[102, 5, 2, 1, 1]',
#   'algo': 'lf',
#   'word': 'tales',
#   'solution': 'aback'},
#  {'steps': 4,
#   'words': ['tales', 'array', 'again', 'aback'],
#   'feedback': "['XYXXX', 'GXXYX', 'GXGXX', 'GGGGG']",
#   'ncands': '[102, 12, 1, 1]',
#   'algo': 'gyx',
#   'word': 'tales',
#   'solution': 'aback'},
#  {'steps': 5,
#   'words': ['tales', 'noria', 'champ', 'quack', 'aback'],
#   'feedback': "['XYXXX', 'XXXXY', 'YXGXX', 'XXGGG', 'GGGGG']",
#   'ncands': '[102, 5, 2, 1, 1]',
#   'algo': 'lf-pop',
#   'word': 'tales',
#   'solution': 'aback'}]

# %%
from scipy import stats

# %%
algos = ['lf', 'gyx', 'lf-pop', 'gyx-pop', 'ncands']
for i, algo in enumerate(algos):
    for j in range(i+1, 5):
        print(f'[ ---- {algo.upper()} vs. {algos[j].upper()} ---- ]')
        test_result = stats.wilcoxon(adf.loc[adf.algo.eq(algo), 'steps'],
                                     adf.loc[adf.algo.eq(algos[j]), 'steps'])
        print(test_result.pvalue)
        print()
# Out:
# [ ---- LF vs. GYX ---- ]
# 1.797283437170917e-127
#
# [ ---- LF vs. LF-POP ---- ]
# 1.8992026938186578e-26
#
# [ ---- LF vs. GYX-POP ---- ]
# 3.336632268244551e-217
#
# [ ---- LF vs. NCANDS ---- ]
# 1.6033209797760188e-197
#
# [ ---- GYX vs. LF-POP ---- ]
# 9.867826038312608e-37
#
# [ ---- GYX vs. GYX-POP ---- ]
# 1.431618768138163e-48
#
# [ ---- GYX vs. NCANDS ---- ]
# 0.0
#
# [ ---- LF-POP vs. GYX-POP ---- ]
# 5.053665492496757e-190
#
# [ ---- LF-POP vs. NCANDS ---- ]
# 8.105101047269212e-304
#
# [ ---- GYX-POP vs. NCANDS ---- ]
# 0.0

# %% [markdown]
# ## Head-to-Head

# %%
h2h = pd.DataFrame()
h2h['solution'] = adf.loc[adf.algo.eq('lf'), 'solution'].values
h2h['lf'] = adf.loc[adf.algo.eq('lf'), 'steps'].values
h2h['gyx'] = adf.loc[adf.algo.eq('gyx'), 'steps'].values
h2h['lf-pop'] = adf.loc[adf.algo.eq('lf-pop'), 'steps'].values
h2h['gyx-pop'] = adf.loc[adf.algo.eq('gyx-pop'), 'steps'].values
h2h['ncands'] = adf.loc[adf.algo.eq('ncands'), 'steps'].values
h2h['entropy'] = adf.loc[adf.algo.eq('entropy'), 'steps'].values

# %%
algos = ['lf', 'gyx', 'lf-pop', 'gyx-pop', 'ncands', 'entropy']
for i, algo in enumerate(algos):
    for j in range(i+1, 5):
        print('----------------------------------')
        print(f'[ ---- {algo.upper()} vs. {algos[j].upper()} ---- ]')
        print(f'{algo.upper()} win: {100*np.mean(h2h[algo] < h2h[algos[j]]):.2f}%')
        print(f'{algos[j].upper()} win: {100*np.mean(h2h[algo] > h2h[algos[j]]):.2f}%')
        print(f'Draw: {100*np.mean(h2h[algo] == h2h[algos[j]]):.2f}%')
        # print('\n')
# Out:
# ----------------------------------
# [ ---- LF vs. GYX ---- ]
# LF win: 33.28%
# GYX win: 22.40%
# Draw: 44.33%
# ----------------------------------
# [ ---- LF vs. LF-POP ---- ]
# LF win: 22.79%
# LF-POP win: 19.55%
# Draw: 57.66%
# ----------------------------------
# [ ---- LF vs. GYX-POP ---- ]
# LF win: 36.50%
# GYX-POP win: 24.43%
# Draw: 39.06%
# ----------------------------------
# [ ---- LF vs. NCANDS ---- ]
# LF win: 21.83%
# NCANDS win: 31.39%
# Draw: 46.78%
# ----------------------------------
# [ ---- GYX vs. LF-POP ---- ]
# GYX win: 27.06%
# LF-POP win: 33.32%
# Draw: 39.62%
# ----------------------------------
# [ ---- GYX vs. GYX-POP ---- ]
# GYX win: 23.68%
# GYX-POP win: 20.04%
# Draw: 56.29%
# ----------------------------------
# [ ---- GYX vs. NCANDS ---- ]
# GYX win: 20.91%
# NCANDS win: 38.36%
# Draw: 40.72%
# ----------------------------------
# [ ---- LF-POP vs. GYX-POP ---- ]
# LF-POP win: 28.57%
# GYX-POP win: 18.14%
# Draw: 53.29%
# ----------------------------------
# [ ---- LF-POP vs. NCANDS ---- ]
# LF-POP win: 21.94%
# NCANDS win: 33.92%
# Draw: 44.14%
# ----------------------------------
# [ ---- GYX-POP vs. NCANDS ---- ]
# GYX-POP win: 20.62%
# NCANDS win: 40.48%
# Draw: 38.90%
