# %% [markdown]
# # Analyse Results

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

sns.set()
fontdict = {'fontsize': 15}

# %% [markdown]
# ## Load Data

# %%
words = ['arles', 'arose', 'dares', 'lares', 'lores', 'nares',
        'raile', 'raise', 'rales', 'rates', 'reais', 'roate',
        'soare', 'stare', 'tales', 'tares', 'tores']

algos = ['lf', 'gyx', 'lf-pop', 'gyx-pop']

# %%
df = pd.DataFrame()
all_data = pd.DataFrame()

for algo in algos:
    print(f'Loading {algo}...')
    for word in words:
        download_path = f'../kernel_output/{algo}/'
        if algo == 'gyx':
            algo_correct = 'expected_gyx'
        elif algo == 'lf-pop':
            algo_correct = 'lf'
        elif algo == 'gyx-pop':
            algo_correct = 'expected_gyx'
        else:
            algo_correct = algo
        filename = f"wordlebot-{algo_correct}-{word}.csv"
        
        if filename in os.listdir(download_path):
            temp_df = pd.read_csv(f'{download_path}{filename}')
            temp_df['algo'] = algo
            all_data = all_data.append(temp_df)
            with open(f"{download_path}wordlebot-{algo}-{word}.log") as f:
                temp_log = f.readlines()
            runtime = pd.DataFrame(eval(''.join(temp_log))).time.iloc[-1]
            temp_results = pd.DataFrame([{
                'Seed Word': word,
                'Ranking Algorithm': algo,
                # 'Runtime': runtime,
                'Mean Steps': temp_df.steps.mean(),
                'Success Rate': temp_df.steps.le(6).mean(),
                '3-Steps or Less': temp_df.steps.le(3).mean(),
                'Worst Case': temp_df.steps.max()
            }])
            
            df = df.append(temp_results)

print('Loading ncands...')
for word in words:
    data_path = '../results'
    filename = f'wordlebot_{word}.csv'
    if filename in os.listdir(data_path):
        temp_df = pd.read_csv(f'{data_path}/{filename}')
        temp_df['algo'] = 'ncands'
        all_data = all_data.append(temp_df)
        temp_results = pd.DataFrame([{
            'Seed Word': word,
            'Ranking Algorithm': 'ncands',
            # 'Runtime': runtime,
            'Mean Steps': temp_df.steps.mean(),
            'Success Rate': temp_df.steps.le(6).mean(),
            '3-Steps or Less': temp_df.steps.le(3).mean(),
            'Worst Case': temp_df.steps.max()
        }])
        df = df.append(temp_results)
# Out:
# Loading lf...
# Loading gyx...
# Loading lf-pop...
# Loading gyx-pop...
# Loading ncands...

# %% [markdown]
# ## Compute Ranking

# %%
metrics = ['Mean Steps', 'Success Rate', '3-Steps or Less']
ascs = [True, False, False]
for metric in metrics:
    x = df[metric]
    df[f'{metric}_score'] = (x - x.min()) / (x.max() - x.min())
    if metric == 'Mean Steps':
        df[f'{metric}_score'] = 1 - df[f'{metric}_score']

df['avg_score'] = df[[f'{s}_score' for s in metrics]].mean(axis=1)

# %% [markdown]
# ### Raw Ranking

# %%
for metric, asc in zip(metrics, ascs):

    print(f'\nBy {metric}:')
    display(df.sort_values(metric, ascending=asc).head(8))
    
print('\nBy Average Score:')
display(df.sort_values('avg_score', ascending=False).head(8))
# Out:
# By Mean Steps:
#   Seed Word Ranking Algorithm  Mean Steps  Success Rate  3-Steps or Less  \
# 0
# 19   0.681752
# 20   0.678684
# 21   0.661219
# 22   0.659499
# 23   0.648329
# 24   0.645187
# 25   0.620020
# 26   0.616579
# 27   0.615226
# 28   0.611555
# 29   0.604919
# 30   0.603741
# 31   0.591457
# 32   0.580057
# 33   0.564154
# 34   0.559435
# 35   0.555124
# 36   0.555011
# 37   0.551715
# 38   0.550833
# 39   0.539262
# 40   0.530077
# 41   0.507332
# 42   0.501799
# 43   0.494794
# 44   0.491667
# 45   0.487302
# 46   0.480012
# 47   0.476534
# 48   0.462421
# 49   0.451871
# 50   0.451382
# 51   0.440199
# 52   0.434538
# 53   0.414688
# 54   0.409906
# 55   0.402363
# 56   0.392586
# 57   0.389781
# 58   0.389430
# 59   0.384597
# 60   0.359136
# 61   0.355790
# 62   0.326439
# 63   0.317537
# 64   0.307672
# 65   0.293550
# 66   0.281507
# 67   0.270885
# 68   0.270314
# 69   0.269992
# 70   0.263877
# 71   0.263491
# 72   0.263423
# 73   0.262729
# 74   0.225318
# 75   0.201573
# 76   0.192524
# 77   0.186468
# 78   0.169361
# 79   0.148703
# 80   0.147207
# 81   0.120230
# 82   0.114878
# 83   0.111259
# 84   0.042424

# %% [markdown]
# ### By Ranking Algorithm

# %%
metric_order = ['ncands', 'lf', 'lf-pop', 'gyx', 'gyx-pop']
for metric, asc in zip(metrics, ascs):

    print(f'\nBy {metric}:')
    display(df.sort_values(metric, ascending=asc).groupby('Ranking Algorithm').first().loc[metric_order])
    
print('\nBy Average Score:')
display(df.sort_values('avg_score', ascending=False).groupby('Ranking Algorithm').first().loc[metric_order])
# Out:
# By Mean Steps:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# ncands                tales    3.601728      0.997408         0.467387
# lf                    stare    3.728726      0.991793         0.423758
# lf-pop                tores    3.770194      0.992225         0.417279
# gyx                   stare    3.831965      0.989201         0.377538
# gyx-pop               tales    3.889849      0.987905         0.366739
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# ncands                      8          1.000000            0.981818
# lf                          9          0.708044            0.745455
# lf-pop                      8          0.612711            0.763636
# gyx                         9          0.470705            0.636364
# gyx-pop                     9          0.337637            0.581818
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# ncands                          0.913978   0.965266
# lf                              0.642473   0.698657
# lf-pop                          0.602151   0.659499
# gyx                             0.354839   0.487302
# gyx-pop                         0.287634   0.402363
# By Success Rate:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# ncands                tares    3.612095      0.997840         0.455724
# lf                    tales    3.749028      0.994384         0.395680
# lf-pop                tores    3.770194      0.992225         0.417279
# gyx                   tales    3.836285      0.990929         0.371058
# gyx-pop               tales    3.889849      0.987905         0.366739
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# ncands                      8          0.976167            1.000000
# lf                          8          0.661370            0.854545
# lf-pop                      8          0.612711            0.763636
# gyx                         9          0.460775            0.709091
# gyx-pop                     9          0.337637            0.581818
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# ncands                          0.841398   0.939188
# lf                              0.467742   0.661219
# lf-pop                          0.602151   0.659499
# gyx                             0.314516   0.494794
# gyx-pop                         0.287634   0.402363
# By 3-Steps or Less:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# ncands                raile    3.606911      0.995248         0.481210
# lf                    arose    3.739525      0.990065         0.429806
# lf-pop                arose    3.782721      0.989201         0.423326
# gyx                   roate    3.837149      0.985745         0.385745
# gyx-pop               roate    3.904968      0.980130         0.379266
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# ncands                      8          0.988083            0.890909
# lf                          8          0.683217            0.672727
# lf-pop                      8          0.583913            0.636364
# gyx                         9          0.458788            0.490909
# gyx-pop                     9          0.302880            0.254545
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# ncands                          1.000000   0.959664
# lf                              0.680108   0.678684
# lf-pop                          0.639785   0.620020
# gyx                             0.405914   0.451871
# gyx-pop                         0.365591   0.307672
# By Average Score:
#                   Seed Word  Mean Steps  Success Rate  3-Steps or Less  \
# Ranking Algorithm
# ncands                tales    3.601728      0.997408         0.467387
# lf                    tores    3.730022      0.991793         0.425054
# lf-pop                tores    3.770194      0.992225         0.417279
# gyx                   tales    3.836285      0.990929         0.371058
# gyx-pop               tales    3.889849      0.987905         0.366739
#
#                    Worst Case  Mean Steps_score  Success Rate_score  \
# Ranking Algorithm
# ncands                      8          1.000000            0.981818
# lf                          8          0.705065            0.745455
# lf-pop                      8          0.612711            0.763636
# gyx                         9          0.460775            0.709091
# gyx-pop                     9          0.337637            0.581818
#
#                    3-Steps or Less_score  avg_score
# Ranking Algorithm
# ncands                          0.913978   0.965266
# lf                              0.650538   0.700352
# lf-pop                          0.602151   0.659499
# gyx                             0.314516   0.494794
# gyx-pop                         0.287634   0.402363

# %%
for metric in metrics:

    df.groupby('Ranking Algorithm')[metric].plot.density(figsize=(10,6))
    plt.legend()
    plt.title(metric, fontdict=fontdict)
    plt.show()
    
df.groupby('Ranking Algorithm')['avg_score'].plot.density(figsize=(10,6))
plt.legend()
plt.title('Average Score', fontdict=fontdict)
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
import statsmodels.api as sm
X = df[['Seed Word', 'Ranking Algorithm']].copy()
X['Popularity'] = X['Ranking Algorithm'].str.contains('pop').astype(int)
X['Ranking Algorithm'] = X['Ranking Algorithm'].str.replace('-pop', '')
X.loc[X['Seed Word'].eq('stare'), 'Seed Word'] = '0stare'
X = pd.get_dummies(X, drop_first=True)
X['const'] = 1.0
y1 = df['Mean Steps']
y2 = df['Success Rate']
y3 = df['3-Steps or Less']

lm_mean_steps = sm.OLS(y1, X)
lm_success_rate = sm.OLS(y2, X)
lm_3steps = sm.OLS(y3, X)

res_mean_steps = lm_mean_steps.fit()
res_success_rate = lm_success_rate.fit()
res_3steps = lm_3steps.fit()

# %%
df.shape
# Out:
# (85, 10)

# %%
res_mean_steps.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Mean Steps   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     138.5
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):           3.97e-45
# Time:                        23:01:55   Log-Likelihood:                 220.23
# No. Observations:                  85   AIC:                            -400.5
# Df Residuals:                      65   BIC:                            -351.6
# Df Model:                          19
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Popularity                   0.0563      0.005     11.199      0.000       0.046       0.066
# Seed Word_arles              0.0505      0.013      3.847      0.000       0.024       0.077
# Seed Word_arose              0.0315      0.013      2.404      0.019       0.005       0.058
# Seed Word_dares              0.0977      0.013      7.449      0.000       0.072       0.124
# Seed Word_lares              0.0569      0.013      4.341      0.000       0.031       0.083
# Seed Word_lores              0.0963      0.013      7.344      0.000       0.070       0.123
# Seed Word_nares              0.0766      0.013      5.842      0.000       0.050       0.103
# Seed Word_raile              0.0454      0.013      3.465      0.001       0.019       0.072
# Seed Word_raise              0.0398      0.013      3.036      0.003       0.014       0.066
# Seed Word_rales              0.0669      0.013      5.098      0.000       0.041       0.093
# Seed Word_rates              0.0498      0.013      3.794      0.000       0.024       0.076
# Seed Word_reais              0.0771      0.013      5.882      0.000       0.051       0.103
# Seed Word_roate              0.0134      0.013      1.021      0.311      -0.013       0.040
# Seed Word_soare              0.0332      0.013      2.529      0.014       0.007       0.059
# Seed Word_tales              0.0077      0.013      0.586      0.560      -0.019       0.034
# Seed Word_tares              0.0093      0.013      0.711      0.479      -0.017       0.036
# Seed Word_tores              0.0175      0.013      1.337      0.186      -0.009       0.044
# Ranking Algorithm_lf        -0.1261      0.005    -25.071      0.000      -0.136      -0.116
# Ranking Algorithm_ncands    -0.2671      0.007    -40.138      0.000      -0.280      -0.254
# const                        3.8507      0.010    385.191      0.000       3.831       3.871
# ==============================================================================
# Omnibus:                       22.750   Durbin-Watson:                   1.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.920
# Skew:                          -0.088   Prob(JB):                       0.0854
# Kurtosis:                       1.834   Cond. No.                         21.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df['resid'] = res_mean_steps.resid

# %%
df.groupby(['Ranking Algorithm']).resid.plot.density()
plt.legend()
plt.show()

# %%
res_mean_steps.resid.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
res_success_rate.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Success Rate   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     36.68
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):           1.61e-27
# Time:                        22:14:24   Log-Likelihood:                 422.81
# No. Observations:                  85   AIC:                            -805.6
# Df Residuals:                      65   BIC:                            -756.8
# Df Model:                          19
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Popularity                  -0.0038      0.000     -8.159      0.000      -0.005      -0.003
# Seed Word_arles             -0.0003      0.001     -0.286      0.776      -0.003       0.002
# Seed Word_arose             -0.0035      0.001     -2.927      0.005      -0.006      -0.001
# Seed Word_dares             -0.0024      0.001     -1.999      0.050      -0.005    -2.5e-06
# Seed Word_lares             -0.0011      0.001     -0.928      0.357      -0.004       0.001
# Seed Word_lores             -0.0028      0.001     -2.285      0.026      -0.005      -0.000
# Seed Word_nares             -0.0021      0.001     -1.714      0.091      -0.004       0.000
# Seed Word_raile             -0.0048      0.001     -3.998      0.000      -0.007      -0.002
# Seed Word_raise             -0.0034      0.001     -2.785      0.007      -0.006      -0.001
# Seed Word_rales             -0.0007      0.001     -0.571      0.570      -0.003       0.002
# Seed Word_rates             -0.0010      0.001     -0.785      0.435      -0.003       0.001
# Seed Word_reais             -0.0035      0.001     -2.927      0.005      -0.006      -0.001
# Seed Word_roate             -0.0018      0.001     -1.499      0.139      -0.004       0.001
# Seed Word_soare             -0.0041      0.001     -3.427      0.001      -0.007      -0.002
# Seed Word_tales              0.0025      0.001      2.071      0.042    8.89e-05       0.005
# Seed Word_tares              0.0003      0.001      0.214      0.831      -0.002       0.003
# Seed Word_tores             -0.0008      0.001     -0.643      0.523      -0.003       0.002
# Ranking Algorithm_lf         0.0068      0.000     14.676      0.000       0.006       0.008
# Ranking Algorithm_ncands     0.0111      0.001     18.007      0.000       0.010       0.012
# const                        0.9865      0.001   1069.698      0.000       0.985       0.988
# ==============================================================================
# Omnibus:                        1.016   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.602   Jarque-Bera (JB):                0.945
# Skew:                          -0.032   Prob(JB):                        0.623
# Kurtosis:                       2.487   Cond. No.                         21.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res_3steps.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        3-Steps or Less   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     90.65
# Date:                Mon, 07 Feb 2022   Prob (F-statistic):           2.29e-39
# Time:                        22:14:24   Log-Likelihood:                 291.35
# No. Observations:                  85   AIC:                            -542.7
# Df Residuals:                      65   BIC:                            -493.8
# Df Model:                          19
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Popularity                  -0.0051      0.002     -2.327      0.023      -0.009      -0.001
# Seed Word_arles             -0.0256      0.006     -4.501      0.000      -0.037      -0.014
# Seed Word_arose             -0.0055      0.006     -0.973      0.334      -0.017       0.006
# Seed Word_dares             -0.0461      0.006     -8.121      0.000      -0.057      -0.035
# Seed Word_lares             -0.0269      0.006     -4.729      0.000      -0.038      -0.016
# Seed Word_lores             -0.0418      0.006     -7.360      0.000      -0.053      -0.030
# Seed Word_nares             -0.0339      0.006     -5.961      0.000      -0.045      -0.023
# Seed Word_raile             -0.0056      0.006     -0.988      0.327      -0.017       0.006
# Seed Word_raise             -0.0098      0.006     -1.734      0.088      -0.021       0.001
# Seed Word_rales             -0.0320      0.006     -5.627      0.000      -0.043      -0.021
# Seed Word_rates             -0.0243      0.006     -4.273      0.000      -0.036      -0.013
# Seed Word_reais             -0.0293      0.006     -5.155      0.000      -0.041      -0.018
# Seed Word_roate              0.0010      0.006      0.182      0.856      -0.010       0.012
# Seed Word_soare             -0.0066      0.006     -1.156      0.252      -0.018       0.005
# Seed Word_tales             -0.0140      0.006     -2.464      0.016      -0.025      -0.003
# Seed Word_tares             -0.0063      0.006     -1.110      0.271      -0.018       0.005
# Seed Word_tores             -0.0052      0.006     -0.912      0.365      -0.017       0.006
# Ranking Algorithm_lf         0.0433      0.002     19.892      0.000       0.039       0.048
# Ranking Algorithm_ncands     0.0998      0.003     34.634      0.000       0.094       0.106
# const                        0.3772      0.004     87.108      0.000       0.369       0.386
# ==============================================================================
# Omnibus:                        9.960   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                3.568
# Skew:                           0.138   Prob(JB):                        0.168
# Kurtosis:                       2.035   Cond. No.                         21.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Diagnosis

# %%
adf = all_data.drop('Unnamed: 0', axis=1)
adf['words'] = adf.words.apply(eval)
adf['word'] = adf.words.apply(lambda x: x[0])
adf['solution'] = adf.words.apply(lambda x: x[-1])
adf = adf.sort_values(['solution', 'word']).reset_index(drop=True)

# %%
solution_scores = adf.groupby('solution').agg({
    'steps': [
        ('Mean Steps', 'mean'),
        ('Success Rate', lambda x: np.mean(x < 7)),
        ('3-Steps or Less', lambda x: np.mean(x <= 3))
    ]
})

# %%
solution_scores.columns = ['Mean Steps', 'Success Rate', '3-Steps or Less']

# %%
df_low_avg_steps = solution_scores.loc[solution_scores['Mean Steps'].gt(6)].sort_values('Mean Steps', ascending=False)
df_low_avg_steps[['Mean Steps']].plot.barh(figsize=(10,7))
plt.gca().invert_yaxis()
plt.title('Solution Words with Average Steps > 6', fontdict=fontdict)
plt.show()
display(df_low_avg_steps)


df_low_success = solution_scores.loc[solution_scores['Success Rate'].lt(0.5)].sort_values('Success Rate', ascending=True)
df_low_success[['Success Rate']].plot.barh(figsize=(10,7))
plt.gca().invert_yaxis()
plt.title('Solution Words with Success Rate < 50%', fontdict=fontdict)
plt.show()
display(df_low_success)

df_zero_3step = solution_scores.loc[solution_scores['3-Steps or Less'].eq(0)].sort_values('Mean Steps', ascending=False)
df_zero_3step[['Mean Steps']].plot.barh(figsize=(10,7))
plt.gca().invert_yaxis()
plt.title('Solution Words with 3-Steps or Less Rate == 0%', fontdict=fontdict)
plt.show()
display(df_zero_3step)
# Out:
#           Mean Steps  Success Rate  3-Steps or Less
# solution
# vaunt       7.376471      0.129412         0.000000
# wound       6.752941      0.200000         0.082353
# graze       6.517647      0.494118         0.000000
# waver       6.458824      0.552941         0.000000
# foyer       6.294118      0.541176         0.011765
# baste       6.258824      0.294118         0.200000
# hound       6.247059      0.435294         0.117647
# joker       6.223529      0.541176         0.011765
# batch       6.164706      0.447059         0.152941
# boxer       6.129412      0.600000         0.011765
# goner       6.047059      0.564706         0.141176
#           Mean Steps  Success Rate  3-Steps or Less
# solution
# vaunt       7.376471      0.129412         0.000000
# wound       6.752941      0.200000         0.082353
# baste       6.258824      0.294118         0.200000
# shave       5.988235      0.400000         0.188235
# hound       6.247059      0.435294         0.117647
# batch       6.164706      0.447059         0.152941
# graze       6.517647      0.494118         0.000000
#           Mean Steps  Success Rate  3-Steps or Less
# solution
# vaunt       7.376471      0.129412              0.0
# graze       6.517647      0.494118              0.0
# waver       6.458824      0.552941              0.0
# ember       5.423529      0.870588              0.0
# gawky       5.352941      0.717647              0.0
# greed       5.341176      0.964706              0.0
# jazzy       5.282353      0.882353              0.0
# stave       5.235294      0.976471              0.0
# swoop       5.235294      0.952941              0.0
# gazer       5.211765      0.800000              0.0
# jiffy       5.011765      1.000000              0.0
# fuzzy       4.941176      0.964706              0.0
# stuff       4.917647      1.000000              0.0
# upper       4.847059      0.976471              0.0
# suave       4.811765      1.000000              0.0
# bezel       4.741176      0.988235              0.0
# fizzy       4.705882      1.000000              0.0
# gravy       4.694118      1.000000              0.0
# jerky       4.658824      1.000000              0.0
# guppy       4.611765      0.964706              0.0
# puffy       4.470588      0.976471              0.0

# %%
adf.loc[adf.word.eq('tales')].to_dict('records')[:3]
# Out:
# [{'steps': 3,
#   'words': ['tales', 'bronc', 'aback'],
#   'feedback': "['XYXXX', 'YXXXY', 'GGGGG']",
#   'ncands': '[102, 1, 1]',
#   'algo': 'ncands',
#   'word': 'tales',
#   'solution': 'aback'},
#  {'steps': 4,
#   'words': ['tales', 'array', 'again', 'aback'],
#   'feedback': "['XYXXX', 'GXXYX', 'GXGXX', 'GGGGG']",
#   'ncands': '[102, 12, 1, 1]',
#   'algo': 'gyx-pop',
#   'word': 'tales',
#   'solution': 'aback'},
#  {'steps': 5,
#   'words': ['tales', 'noria', 'champ', 'quack', 'aback'],
#   'feedback': "['XYXXX', 'XXXXY', 'YXGXX', 'XXGGG', 'GGGGG']",
#   'ncands': '[102, 5, 2, 1, 1]',
#   'algo': 'lf-pop',
#   'word': 'tales',
#   'solution': 'aback'}]

# %%
from scipy import stats

# %%
algos = ['lf', 'gyx', 'lf-pop', 'gyx-pop', 'ncands']
for i, algo in enumerate(algos):
    for j in range(i+1, 5):
        print(f'[ ---- {algo.upper()} vs. {algos[j].upper()} ---- ]')
        test_result = stats.wilcoxon(adf.loc[adf.algo.eq(algo), 'steps'],
                                     adf.loc[adf.algo.eq(algos[j]), 'steps'])
        print(test_result.pvalue)
        print()
# Out:
# [ ---- LF vs. GYX ---- ]
# 1.797283437170917e-127
#
# [ ---- LF vs. LF-POP ---- ]
# 1.8992026938186578e-26
#
# [ ---- LF vs. GYX-POP ---- ]
# 3.336632268244551e-217
#
# [ ---- LF vs. NCANDS ---- ]
# 1.6033209797760188e-197
#
# [ ---- GYX vs. LF-POP ---- ]
# 9.867826038312608e-37
#
# [ ---- GYX vs. GYX-POP ---- ]
# 1.431618768138163e-48
#
# [ ---- GYX vs. NCANDS ---- ]
# 0.0
#
# [ ---- LF-POP vs. GYX-POP ---- ]
# 5.053665492496757e-190
#
# [ ---- LF-POP vs. NCANDS ---- ]
# 8.105101047269212e-304
#
# [ ---- GYX-POP vs. NCANDS ---- ]
# 0.0

# %%
adf.loc[adf.algo.eq('ncands'), 'steps']
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Head-to-Head

# %%
h2h = pd.DataFrame()
h2h['solution'] = adf.loc[adf.algo.eq('lf'), 'solution'].values
h2h['lf'] = adf.loc[adf.algo.eq('lf'), 'steps'].values
h2h['gyx'] = adf.loc[adf.algo.eq('gyx'), 'steps'].values
h2h['lf-pop'] = adf.loc[adf.algo.eq('lf-pop'), 'steps'].values
h2h['gyx-pop'] = adf.loc[adf.algo.eq('gyx-pop'), 'steps'].values
h2h['ncands'] = adf.loc[adf.algo.eq('ncands'), 'steps'].values

# %%
algos = ['lf', 'gyx', 'lf-pop', 'gyx-pop', 'ncands']
for i, algo in enumerate(algos):
    for j in range(i+1, 5):
        print('----------------------------------')
        print(f'[ ---- {algo.upper()} vs. {algos[j].upper()} ---- ]')
        print(f'{algo.upper()} win: {100*np.mean(h2h[algo] < h2h[algos[j]]):.2f}%')
        print(f'{algos[j].upper()} win: {100*np.mean(h2h[algo] > h2h[algos[j]]):.2f}%')
        print(f'Draw: {100*np.mean(h2h[algo] == h2h[algos[j]]):.2f}%')
        # print('\n')
# Out:
# ----------------------------------
# [ ---- LF vs. GYX ---- ]
# LF win: 36.02%
# GYX win: 26.12%
# Draw: 37.87%
# ----------------------------------
# [ ---- LF vs. LF-POP ---- ]
# LF win: 30.97%
# LF-POP win: 28.54%
# Draw: 40.49%
# ----------------------------------
# [ ---- LF vs. GYX-POP ---- ]
# LF win: 38.38%
# GYX-POP win: 26.97%
# Draw: 34.65%
# ----------------------------------
# [ ---- LF vs. NCANDS ---- ]
# LF win: 24.68%
# NCANDS win: 33.86%
# Draw: 41.47%
# ----------------------------------
# [ ---- GYX vs. LF-POP ---- ]
# GYX win: 29.57%
# LF-POP win: 35.33%
# Draw: 35.10%
# ----------------------------------
# [ ---- GYX vs. GYX-POP ---- ]
# GYX win: 32.73%
# GYX-POP win: 29.81%
# Draw: 37.47%
# ----------------------------------
# [ ---- GYX vs. NCANDS ---- ]
# GYX win: 23.18%
# NCANDS win: 40.01%
# Draw: 36.81%
# ----------------------------------
# [ ---- LF-POP vs. GYX-POP ---- ]
# LF-POP win: 33.96%
# GYX-POP win: 24.09%
# Draw: 41.95%
# ----------------------------------
# [ ---- LF-POP vs. NCANDS ---- ]
# LF-POP win: 24.68%
# NCANDS win: 36.14%
# Draw: 39.18%
# ----------------------------------
# [ ---- GYX-POP vs. NCANDS ---- ]
# GYX-POP win: 23.09%
# NCANDS win: 42.02%
# Draw: 34.89%

# %%
import statsmodels.api as sm

X = adf[['word', 'algo', 'solution']].copy()
X['popularity'] = X['algo'].str.contains('pop').astype(int)
X['algo'] = X['algo'].str.replace('-pop', '')
X.loc[X['word'].eq('stare'), 'word'] = '0stare'
X = pd.get_dummies(X, drop_first=True)
X['const'] = 1.0

y = adf['steps']

lm_steps = sm.GLM(y, X, family=sm.families.Poisson())
res_steps = lm_steps.fit()

# %%
res_steps.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  steps   No. Observations:               196775
# Model:                            GLM   Df Residuals:                   196755
# Model Family:                 Poisson   Df Model:                           19
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -3.3657e+05
# Date:                Mon, 07 Feb 2022   Deviance:                       44938.
# Time:                        23:17:05   Pearson chi2:                 4.61e+04
# No. Iterations:                     4   Pseudo R-squ. (CS):           0.003501
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# popularity      0.0146      0.003      5.687      0.000       0.010       0.020
# word_arles      0.0133      0.007      1.970      0.049    7.02e-05       0.027
# word_arose      0.0083      0.007      1.233      0.218      -0.005       0.022
# word_dares      0.0256      0.007      3.804      0.000       0.012       0.039
# word_lares      0.0150      0.007      2.222      0.026       0.002       0.028
# word_lores      0.0252      0.007      3.751      0.000       0.012       0.038
# word_nares      0.0201      0.007      2.987      0.003       0.007       0.033
# word_raile      0.0120      0.007      1.775      0.076      -0.001       0.025
# word_raise      0.0105      0.007      1.556      0.120      -0.003       0.024
# word_rales      0.0176      0.007      2.609      0.009       0.004       0.031
# word_rates      0.0131      0.007      1.943      0.052      -0.000       0.026
# word_reais      0.0203      0.007      3.008      0.003       0.007       0.033
# word_roate      0.0035      0.007      0.524      0.600      -0.010       0.017
# word_soare      0.0088      0.007      1.297      0.195      -0.004       0.022
# word_tales      0.0020      0.007      0.301      0.763      -0.011       0.015
# word_tares      0.0025      0.007      0.365      0.715      -0.011       0.016
# word_tores      0.0046      0.007      0.686      0.492      -0.009       0.018
# algo_lf        -0.0327      0.003    -12.731      0.000      -0.038      -0.028
# algo_ncands    -0.0709      0.003    -20.544      0.000      -0.078      -0.064
# const           1.3479      0.005    261.867      0.000       1.338       1.358
# ===============================================================================
# """
